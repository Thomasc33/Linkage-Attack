# %% [markdown]
# ## Imports / Globals

# %%
import pickle
import pandas as pd
from os import listdir
from os.path import isfile, join
from tqdm import tqdm
import numpy as np
from sklearn.model_selection import train_test_split

np.random.seed(42)

# %%
# path = '/Users/thomas/Downloads/nturgb+d_skeletons'
path = 'D:\\Datasets\\Motion Privacy\\NTU RGB+D 120\\Skeleton Data'

# %% [markdown]
# ## Data organization

# %% [markdown]
# ### Input format
# needs to be updated
#
# [J0 X, J0 Y, J0 Z, J1 X, J1 Y, J1 Z, ..., J25 Z]
#
# ### Output format
# One Hot encoded action classification len(Y) = 106

# %%
def load_files():
    # Read the files
    files = [f for f in listdir(path) if isfile(join(path, f))]

    # Get stats for each file based on name
    files_ = []
    for file in files:
        data = {'file': file,
                's': file[0:4],
                'c': file[4:8],
                'p': file[8:12],
                'r': file[12:16],
                'a': file[16:20]
                }
        files_.append(data)

    return files_
files_ = None

# %%
# Attempt to load X and Y from pickle before generating them
X = {}
try:
    print('Attempting to load X from pickle')
    with open('data/X_reidentification.pkl', 'rb') as f:
        X = pickle.load(f)
    print('X loaded from pickle')
except:
    print('Could not load X and Y, generating them now')

    # Load the files
    if files_ is None:
        files_ = load_files()

    # Generate X and Y
    for file_ in tqdm(files_, desc='Files Parsed', position=0, miniters=200):
        try:
            file = join(path, file_['file'])
            data = open(file, 'r')
            lines = data.readlines()
            frames_count = int(lines.pop(0).replace('\n', ''))
            file_['frames'] = frames_count
        except UnicodeDecodeError:  # .DS_Store file
            print('UnicodeDecodeError: ', file)
            continue

        # Get P and add to X if not already there
        a = file_['p']
        if a not in X:
            X[a] = []

        # Hold all frames for the file (action)
        frames = []

        # To validate the video is good
        good = True

        for f in tqdm(range(frames_count), desc='Frames Parsed', position=1, leave=False):
            try:
                # Get actor count
                actors = int(lines.pop(0).replace('\n', ''))

                # Hold frame info
                frame = []

                # Iterate through actors
                for ac in range(actors):
                    # Get actor info
                    t = lines.pop(0)

                    # Get joint count
                    joint_count = int(lines.pop(0).replace('\n', ''))

                    # Get joint info
                    d = []
                    for j in range(joint_count):
                        joint = lines.pop(0).replace('\n', '').split(' ')
                        d.extend(joint[0:3])

                    # Convert to float
                    d = [float(i) for i in d]

                    # Skip if not 25 joints
                    if len(d) != 75:
                        good = False
                        break

                    # Append to frame
                    frame.extend(d)

                # Convert to numpy array
                frame = np.array(frame, dtype=np.float32)

                # Pad frame to 150 (for 2 actors)
                if len(frame) < 150:
                    frame = np.pad(frame, (0, 150-len(frame)), 'constant')

                # Append to X and Y
                frames.append(frame)
            except:
                break

        if not good:
            continue

        if type(frames) != list:
            print('Not a list: ', type(frames), frames)
            continue

        # Convert to numpy array
        frames = np.array(frames, dtype=np.ndarray)

        # Validate frames size
        if len(frames.shape) != 2 or frames.shape[1] < 150:
            continue

        # Pad X size to 300 frames (300 is max frames in dataset)
        # Each frame is 25 joints * 3 coordinates * 2 potential actors = 150
        # For the real time attack model, we can make a new prediction every 300 frames (5 second @ 60fps) to align with this
        if frames.shape[0] < 300:
            frames = np.pad(
                frames, ((0, 300-frames.shape[0]), (0, 0)), 'constant')

        # Validate frames size
        if frames.shape != (300, 150):
            continue

        # Ensure the frame isnt all zeros
        if np.sum(frames) == 0:
            continue

        # Add frames to X
        X[a].append(frames)

    # Convert to numpy arrays
    for a in X:
        X[a] = np.array(X[a]).astype(np.float32)

    print('X Generated, saving to pickle...')

    # Save the data
    with open('data/X_reidentification.pkl', 'wb') as f:
        pickle.dump(X, f)

    print('X Saved to pickle')

# Print Lengths
# for p in X:
#     print(p, len(X[p]))
# Out:
# Attempting to load X from pickle
# Could not load X and Y, generating them now
# Files Parsed: 100%|██████████| 114480/114480 [1:21:42<00:00, 23.35it/s]
# X Generated, saving to pickle...
# X Saved to pickle

# %%
def process_data():
    x=[]
    y=[]
    for action in X:
        # Get the action index
        action_index = int(action[1:4])-1
        # Convert to onehot encoding
        y_ = np.zeros(106)
        y_[action_index] = 1
        # Append to X and Y
        y.extend([y_]*len(X[action]))
        x.extend(X[action])
    return x,y

X_, Y_ = process_data()

# %%
# Split into train and test
train_x, test_x, train_y, test_y = train_test_split(X_, Y_, test_size=0.3, random_state=42)
# Split into validation and test
val_x, test_x, val_y, test_y = train_test_split(test_x, test_y, test_size=0.5, random_state=42)

# %% [markdown]
# ## SGN
#
# All code in this section is adapted from Microsoft's SGN. [Github](https://github.com/microsoft/SGN)

# %%
import time
import shutil
import os
import os.path as osp
import csv
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import MultiStepLR
from model import SGN
from data import NTUDataLoaders, AverageMeter
from util import make_dir, get_num_classes

# %%
# Hyperparameters/Tuning Parameters
network='SGN'
dataset='NTU'
start_epoch=0
case=2 # 0 = Gender, 1 = Action, 2 = Reidentification
batch_size=64
max_epochs=300
monitor='val_acc'
lr=0.001
weight_decay=0.0001
lr_factor=0.1
workers=16
print_freq = 20
do_train=1
seg=20

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    losses = AverageMeter()
    acces = AverageMeter()
    model.train()

    for i, (inputs, target) in enumerate(train_loader):

        output = model(inputs.cuda())
        target = target.cuda()
        loss = criterion(output, target)

        # measure accuracy and record loss
        acc = accuracy(output.data, target)
        losses.update(loss.item(), inputs.size(0))
        acces.update(acc[0], inputs.size(0))

        # backward
        optimizer.zero_grad()  # clear gradients out before each mini-batch
        loss.backward()
        optimizer.step()

        if (i + 1) % print_freq == 0:
            print('Epoch-{:<3d} {:3d} batches\t'
                  'loss {loss.val:.4f} ({loss.avg:.4f})\t'
                  'accu {acc.val:.3f} ({acc.avg:.3f})'.format(
                      epoch + 1, i + 1, loss=losses, acc=acces))

    return losses.avg, acces.avg


def validate(val_loader, model, criterion):
    losses = AverageMeter()
    acces = AverageMeter()
    model.eval()

    for i, (inputs, target) in enumerate(val_loader):
        with torch.no_grad():
            output = model(inputs.cuda())
        target = target.cuda()
        with torch.no_grad():
            loss = criterion(output, target)

        # measure accuracy and record loss
        acc = accuracy(output.data, target)
        losses.update(loss.item(), inputs.size(0))
        acces.update(acc[0], inputs.size(0))

    return losses.avg, acces.avg


def test(test_loader, model, checkpoint, lable_path, pred_path):
    acces = AverageMeter()
    # load learnt model that obtained best performance on validation set
    model.load_state_dict(torch.load(checkpoint)['state_dict'])
    model.eval()

    label_output = list()
    pred_output = list()

    t_start = time.time()
    for i, t in enumerate(test_loader):
        inputs = t[0]
        target = t[1]
        with torch.no_grad():
            output = model(inputs.cuda())
            output = output.view(
                (-1, inputs.size(0)//target.size(0), output.size(1)))
            output = output.mean(1)

        label_output.append(target.cpu().numpy())
        pred_output.append(output.cpu().numpy())

        acc = accuracy(output.data, target.cuda())
        acces.update(acc[0], inputs.size(0))

    label_output = np.concatenate(label_output, axis=0)
    np.savetxt(lable_path, label_output, fmt='%d')
    pred_output = np.concatenate(pred_output, axis=0)
    np.savetxt(pred_path, pred_output, fmt='%f')

    print('Test: accuracy {:.3f}, time: {:.2f}s'
          .format(acces.avg, time.time() - t_start))


def accuracy(output, target):
    batch_size = target.size(0)
    _, pred = output.topk(1, 1, True, True)
    pred = pred.t()
    target = torch.argmax(target, dim=1)  # Add this line to convert one-hot targets to class indices
    correct = pred.eq(target.view(1, -1).expand_as(pred))
    correct = correct.view(-1).float().sum(0, keepdim=True)
    return correct.mul_(100.0 / batch_size)



def save_checkpoint(state, filename='checkpoint.pth.tar', is_best=False):
    torch.save(state, filename)
    if is_best:
        shutil.copyfile(filename, 'model_best.pth.tar')


def get_n_params(model):
    pp = 0
    for p in list(model.parameters()):
        nn = 1
        for s in list(p.size()):
            nn = nn*s
        pp += nn
    return pp


class LabelSmoothingLoss(nn.Module):
    def __init__(self, classes, smoothing=0.0, dim=-1):
        super(LabelSmoothingLoss, self).__init__()
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.cls = classes
        self.dim = dim

    def forward(self, pred, target):
        pred = pred.log_softmax(dim=self.dim)
        with torch.no_grad():
            target = torch.argmax(target, dim=1)  # Add this line to convert one-hot targets to class indices
            true_dist = torch.zeros_like(pred)
            true_dist.fill_(self.smoothing / (self.cls - 1))
            true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        return torch.mean(torch.sum(-true_dist * pred, dim=self.dim))

# %%
def main():
    num_classes = get_num_classes(dataset, 2)
    model = SGN(num_classes, dataset, seg, batch_size, do_train)

    total = get_n_params(model)
    # print(model)
    print('The number of parameters: ', total)
    print('The modes is:', network)

    if torch.cuda.is_available():
        print('It is using GPU!')
        model = model.cuda()

    criterion = LabelSmoothingLoss(num_classes, smoothing=0.1).cuda()
    optimizer = optim.Adam(model.parameters(), lr=lr,
                           weight_decay=weight_decay)

    if monitor == 'val_acc':
        mode = 'max'
        monitor_op = np.greater
        best = -np.Inf
        str_op = 'improve'
    elif monitor == 'val_loss':
        mode = 'min'
        monitor_op = np.less
        best = np.Inf
        str_op = 'reduce'

    scheduler = MultiStepLR(optimizer, milestones=[60, 90, 110], gamma=0.1)
    # Data loading
    ntu_loaders = NTUDataLoaders(dataset, case, seg=seg, train_X=train_x, train_Y=train_y, test_X=test_x, test_Y=test_y, val_X=val_x, val_Y=val_y, aug=0)
    train_loader = ntu_loaders.get_train_loader(batch_size, workers)
    val_loader = ntu_loaders.get_val_loader(batch_size, workers)
    train_size = ntu_loaders.get_train_size()
    val_size = ntu_loaders.get_val_size()

    test_loader = ntu_loaders.get_test_loader(32, workers)

    print('Train on %d samples, validate on %d samples' %
          (train_size, val_size))

    best_epoch = 0
    output_dir = make_dir(dataset)

    save_path = os.path.join(output_dir, network)
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    checkpoint = osp.join(save_path, '%s_best.pth' % case)
    earlystop_cnt = 0
    csv_file = osp.join(save_path, '%s_log.csv' % case)
    log_res = list()

    lable_path = osp.join(save_path, '%s_lable.txt' % case)
    pred_path = osp.join(save_path, '%s_pred.txt' % case)

    # Training
    if do_train == 1:
        for epoch in range(start_epoch, max_epochs):

            print(epoch, optimizer.param_groups[0]['lr'])

            t_start = time.time()
            train_loss, train_acc = train(
                train_loader, model, criterion, optimizer, epoch)
            val_loss, val_acc = validate(val_loader, model, criterion)
            log_res += [[train_loss, train_acc.cpu().numpy(),
                         val_loss, val_acc.cpu().numpy()]]

            print('Epoch-{:<3d} {:.1f}s\t'
                  'Train: loss {:.4f}\taccu {:.4f}\tValid: loss {:.4f}\taccu {:.4f}'
                  .format(epoch + 1, time.time() - t_start, train_loss, train_acc, val_loss, val_acc))

            current = val_loss if mode == 'min' else val_acc

            # store tensor in cpu
            current = current.cpu()

            if monitor_op(current, best):
                print('Epoch %d: %s %sd from %.4f to %.4f, '
                      'saving model to %s'
                      % (epoch + 1, monitor, str_op, best, current, checkpoint))
                best = current
                best_epoch = epoch + 1
                save_checkpoint({
                    'epoch': epoch + 1,
                    'state_dict': model.state_dict(),
                    'best': best,
                    'monitor': monitor,
                    'optimizer': optimizer.state_dict(),
                }, checkpoint)
                earlystop_cnt = 0
            else:
                print('Epoch %d: %s did not %s' % (epoch + 1, monitor, str_op))
                earlystop_cnt += 1

            scheduler.step()

        print('Best %s: %.4f from epoch-%d' % (monitor, best, best_epoch))
        with open(csv_file, 'w') as fw:
            cw = csv.writer(fw)
            cw.writerow(['loss', 'acc', 'val_loss', 'val_acc'])
            cw.writerows(log_res)
        print('Save train and validation log into into %s' % csv_file)

    # Test
    model = SGN(num_classes, dataset, seg, batch_size, 0)
    model = model.cuda()
    test(test_loader, model, checkpoint, lable_path, pred_path)

main()
# Out:
# The number of parameters:  714646
# The modes is: SGN
# It is using GPU!
# Train on 79083 samples, validate on 16947 samples
# 0 0.001
# Epoch-1    20 batches	loss 4.5035 (4.6302)	accu 4.688 (5.000)
# Epoch-1    40 batches	loss 4.3776 (4.4392)	accu 9.375 (7.617)
# Epoch-1    60 batches	loss 4.2147 (4.3543)	accu 6.250 (7.891)
# Epoch-1    80 batches	loss 4.1950 (4.2933)	accu 9.375 (8.242)
# Epoch-1   100 batches	loss 4.1130 (4.2461)	accu 4.688 (8.531)
# Epoch-1   120 batches	loss 4.0307 (4.1947)	accu 6.250 (8.945)
# Epoch-1   140 batches	loss 3.7700 (4.1655)	accu 10.938 (9.029)
# Epoch-1   160 batches	loss 4.0165 (4.1273)	accu 7.812 (9.297)
# Epoch-1   180 batches	loss 3.7339 (4.0928)	accu 12.500 (9.688)
# Epoch-1   200 batches	loss 3.8338 (4.0633)	accu 10.938 (10.016)
# Epoch-1   220 batches	loss 3.6797 (4.0306)	accu 9.375 (10.355)
# Epoch-1   240 batches	loss 3.6527 (4.0030)	accu 9.375 (10.579)
# Epoch-1   260 batches	loss 3.7596 (3.9763)	accu 6.250 (10.823)
# Epoch-1   280 batches	loss 3.5664 (3.9456)	accu 17.188 (11.116)
# Epoch-1   300 batches	loss 3.6758 (3.9249)	accu 12.500 (11.349)
# Epoch-1   320 batches	loss 3.6776 (3.9006)	accu 15.625 (11.680)
# Epoch-1   340 batches	loss 3.4316 (3.8768)	accu 21.875 (11.857)
# Epoch-1   360 batches	loss 3.4424 (3.8542)	accu 10.938 (12.049)
# Epoch-1   380 batches	loss 3.3920 (3.8295)	accu 18.750 (12.401)
# Epoch-1   400 batches	loss 3.2640 (3.8098)	accu 18.750 (12.605)
# Epoch-1   420 batches	loss 3.3488 (3.7908)	accu 20.312 (12.913)
# Epoch-1   440 batches	loss 3.3284 (3.7721)	accu 21.875 (13.125)
# Epoch-1   460 batches	loss 3.2389 (3.7529)	accu 21.875 (13.421)
# Epoch-1   480 batches	loss 3.3206 (3.7337)	accu 23.438 (13.701)
# Epoch-1   500 batches	loss 3.1488 (3.7203)	accu 26.562 (13.875)
# Epoch-1   520 batches	loss 3.5116 (3.7058)	accu 12.500 (14.029)
# Epoch-1   540 batches	loss 3.3329 (3.6891)	accu 17.188 (14.280)
# Epoch-1   560 batches	loss 3.2374 (3.6732)	accu 23.438 (14.461)
# Epoch-1   580 batches	loss 3.3426 (3.6581)	accu 10.938 (14.712)
# Epoch-1   600 batches	loss 3.3542 (3.6432)	accu 12.500 (14.880)
# Epoch-1   620 batches	loss 3.3167 (3.6277)	accu 20.312 (15.134)
# Epoch-1   640 batches	loss 3.1322 (3.6149)	accu 20.312 (15.283)
# Epoch-1   660 batches	loss 3.2186 (3.6036)	accu 18.750 (15.464)
# Epoch-1   680 batches	loss 3.2080 (3.5889)	accu 17.188 (15.692)
# Epoch-1   700 batches	loss 2.9788 (3.5776)	accu 34.375 (15.891)
# Epoch-1   720 batches	loss 3.0778 (3.5649)	accu 20.312 (16.076)
# Epoch-1   740 batches	loss 3.4059 (3.5538)	accu 17.188 (16.256)
# Epoch-1   760 batches	loss 3.0233 (3.5418)	accu 28.125 (16.460)
# Epoch-1   780 batches	loss 2.8985 (3.5290)	accu 35.938 (16.681)
# Epoch-1   800 batches	loss 2.9281 (3.5187)	accu 31.250 (16.816)
# Epoch-1   820 batches	loss 3.1814 (3.5085)	accu 21.875 (16.925)
# Epoch-1   840 batches	loss 3.0066 (3.4982)	accu 25.000 (17.068)
# Epoch-1   860 batches	loss 3.1258 (3.4879)	accu 21.875 (17.262)
# Epoch-1   880 batches	loss 3.1256 (3.4777)	accu 25.000 (17.456)
# Epoch-1   900 batches	loss 3.0421 (3.4683)	accu 26.562 (17.622)
# Epoch-1   920 batches	loss 2.9420 (3.4577)	accu 20.312 (17.790)
# Epoch-1   940 batches	loss 2.8181 (3.4473)	accu 31.250 (17.962)
# Epoch-1   960 batches	loss 2.9455 (3.4382)	accu 23.438 (18.132)
# Epoch-1   980 batches	loss 3.0149 (3.4287)	accu 31.250 (18.327)
# Epoch-1   1000 batches	loss 2.8493 (3.4186)	accu 28.125 (18.520)
# Epoch-1   1020 batches	loss 3.0054 (3.4098)	accu 20.312 (18.670)
# Epoch-1   1040 batches	loss 2.9816 (3.4020)	accu 23.438 (18.807)
# Epoch-1   1060 batches	loss 3.3598 (3.3936)	accu 18.750 (18.981)
# Epoch-1   1080 batches	loss 2.9921 (3.3852)	accu 20.312 (19.136)
# Epoch-1   1100 batches	loss 2.8042 (3.3774)	accu 40.625 (19.283)
# Epoch-1   1120 batches	loss 2.8082 (3.3695)	accu 34.375 (19.435)
# Epoch-1   1140 batches	loss 3.1177 (3.3611)	accu 21.875 (19.590)
# Epoch-1   1160 batches	loss 2.9168 (3.3528)	accu 21.875 (19.756)
# Epoch-1   1180 batches	loss 2.8154 (3.3445)	accu 34.375 (19.928)
# Epoch-1   1200 batches	loss 3.0938 (3.3372)	accu 26.562 (20.068)
# Epoch-1   1220 batches	loss 2.7120 (3.3296)	accu 32.812 (20.211)
# Epoch-1   267.9s	Train: loss 3.3232	accu 20.3327	Valid: loss 2.6609	accu 36.7957
# Epoch 1: val_acc improved from -inf to 36.7957, saving model to ./results/NTU/SGN\2_best.pth
# 1 0.001
# Epoch-2    20 batches	loss 2.6399 (2.8502)	accu 42.188 (30.156)
# Epoch-2    40 batches	loss 2.5988 (2.7956)	accu 34.375 (30.781)
# Epoch-2    60 batches	loss 2.4380 (2.7749)	accu 48.438 (31.953)
# Epoch-2    80 batches	loss 2.9339 (2.7802)	accu 34.375 (32.168)
# Epoch-2   100 batches	loss 2.7606 (2.7803)	accu 35.938 (32.422)
# Epoch-2   120 batches	loss 2.7539 (2.7809)	accu 32.812 (32.383)
# Epoch-2   140 batches	loss 3.1904 (2.7829)	accu 17.188 (32.321)
# Epoch-2   160 batches	loss 2.8184 (2.7820)	accu 31.250 (32.354)
# Epoch-2   180 batches	loss 2.7201 (2.7824)	accu 32.812 (32.240)
# Epoch-2   200 batches	loss 2.6820 (2.7799)	accu 35.938 (32.398)
# Epoch-2   220 batches	loss 2.6962 (2.7707)	accu 29.688 (32.720)
# Epoch-2   240 batches	loss 2.5091 (2.7685)	accu 46.875 (32.819)
# Epoch-2   260 batches	loss 2.8734 (2.7643)	accu 21.875 (32.957)
# Epoch-2   280 batches	loss 2.9842 (2.7611)	accu 29.688 (33.108)
# Epoch-2   300 batches	loss 2.6444 (2.7569)	accu 39.062 (33.234)
# Epoch-2   320 batches	loss 2.9313 (2.7530)	accu 23.438 (33.301)
# Epoch-2   340 batches	loss 2.4824 (2.7476)	accu 42.188 (33.401)
# Epoch-2   360 batches	loss 2.6106 (2.7440)	accu 37.500 (33.520)
# Epoch-2   380 batches	loss 2.8213 (2.7411)	accu 35.938 (33.581)
# Epoch-2   400 batches	loss 2.6449 (2.7367)	accu 29.688 (33.691)
# Epoch-2   420 batches	loss 2.7266 (2.7342)	accu 32.812 (33.798)
# Epoch-2   440 batches	loss 2.8986 (2.7320)	accu 32.812 (33.849)
# Epoch-2   460 batches	loss 2.4749 (2.7327)	accu 46.875 (33.808)
# Epoch-2   480 batches	loss 2.8379 (2.7292)	accu 28.125 (33.867)
# Epoch-2   500 batches	loss 2.4940 (2.7242)	accu 40.625 (34.025)
# Epoch-2   520 batches	loss 2.4564 (2.7204)	accu 42.188 (34.207)
# Epoch-2   540 batches	loss 2.5290 (2.7194)	accu 35.938 (34.187)
# Epoch-2   560 batches	loss 2.4471 (2.7141)	accu 43.750 (34.283)
# Epoch-2   580 batches	loss 2.3899 (2.7102)	accu 48.438 (34.434)
# Epoch-2   600 batches	loss 2.3001 (2.7067)	accu 51.562 (34.583)
# Epoch-2   620 batches	loss 2.6489 (2.7040)	accu 28.125 (34.677)
# Epoch-2   640 batches	loss 2.6604 (2.7025)	accu 42.188 (34.709)
# Epoch-2   660 batches	loss 2.7047 (2.7007)	accu 32.812 (34.721)
# Epoch-2   680 batches	loss 2.6047 (2.6962)	accu 42.188 (34.835)
# Epoch-2   700 batches	loss 2.6161 (2.6929)	accu 34.375 (34.953)
# Epoch-2   720 batches	loss 2.5469 (2.6909)	accu 37.500 (34.987)
# Epoch-2   740 batches	loss 2.5792 (2.6877)	accu 39.062 (35.133)
# Epoch-2   760 batches	loss 2.4902 (2.6842)	accu 40.625 (35.290)
# Epoch-2   780 batches	loss 2.6785 (2.6825)	accu 43.750 (35.335)
# Epoch-2   800 batches	loss 2.3555 (2.6780)	accu 45.312 (35.479)
# Epoch-2   820 batches	loss 2.4261 (2.6755)	accu 40.625 (35.602)
# Epoch-2   840 batches	loss 2.6147 (2.6712)	accu 32.812 (35.746)
# Epoch-2   860 batches	loss 2.3963 (2.6682)	accu 40.625 (35.823)
# Epoch-2   880 batches	loss 2.5876 (2.6665)	accu 43.750 (35.868)
# Epoch-2   900 batches	loss 2.5361 (2.6638)	accu 35.938 (35.969)
# Epoch-2   920 batches	loss 2.2888 (2.6599)	accu 37.500 (36.090)
# Epoch-2   940 batches	loss 2.3954 (2.6566)	accu 42.188 (36.225)
# Epoch-2   960 batches	loss 2.5593 (2.6545)	accu 37.500 (36.313)
# Epoch-2   980 batches	loss 2.7568 (2.6516)	accu 29.688 (36.408)
# Epoch-2   1000 batches	loss 2.5957 (2.6495)	accu 35.938 (36.486)
# Epoch-2   1020 batches	loss 2.4754 (2.6463)	accu 31.250 (36.589)
# Epoch-2   1040 batches	loss 2.4777 (2.6429)	accu 28.125 (36.680)
# Epoch-2   1060 batches	loss 2.6103 (2.6392)	accu 34.375 (36.812)
# Epoch-2   1080 batches	loss 2.6724 (2.6372)	accu 35.938 (36.897)
# Epoch-2   1100 batches	loss 2.4828 (2.6351)	accu 40.625 (36.962)
# Epoch-2   1120 batches	loss 2.4522 (2.6317)	accu 42.188 (37.048)
# Epoch-2   1140 batches	loss 2.2529 (2.6294)	accu 46.875 (37.141)
# Epoch-2   1160 batches	loss 2.2887 (2.6263)	accu 46.875 (37.214)
# Epoch-2   1180 batches	loss 2.5786 (2.6234)	accu 35.938 (37.303)
# Epoch-2   1200 batches	loss 2.4821 (2.6195)	accu 37.500 (37.415)
# Epoch-2   1220 batches	loss 2.6208 (2.6167)	accu 34.375 (37.499)
# Epoch-2   252.3s	Train: loss 2.6148	accu 37.5822	Valid: loss 2.2224	accu 51.5329
# Epoch 2: val_acc improved from 36.7957 to 51.5329, saving model to ./results/NTU/SGN\2_best.pth
# 2 0.001
# Epoch-3    20 batches	loss 2.4034 (2.3641)	accu 42.188 (46.250)
# Epoch-3    40 batches	loss 2.3315 (2.3818)	accu 46.875 (45.391)
# Epoch-3    60 batches	loss 2.3250 (2.3720)	accu 43.750 (45.833)
# Epoch-3    80 batches	loss 2.1937 (2.3804)	accu 48.438 (45.684)
# Epoch-3   100 batches	loss 2.1735 (2.3647)	accu 56.250 (46.297)
# Epoch-3   120 batches	loss 2.3404 (2.3731)	accu 51.562 (46.276)
# Epoch-3   140 batches	loss 2.1545 (2.3738)	accu 54.688 (46.138)
# Epoch-3   160 batches	loss 2.3479 (2.3819)	accu 40.625 (45.771)
# Epoch-3   180 batches	loss 2.2509 (2.3823)	accu 53.125 (45.859)
# Epoch-3   200 batches	loss 2.1970 (2.3813)	accu 53.125 (45.758)
# Epoch-3   220 batches	loss 2.3050 (2.3874)	accu 48.438 (45.398)
# Epoch-3   240 batches	loss 2.2876 (2.3914)	accu 42.188 (45.391)
# Epoch-3   260 batches	loss 2.2721 (2.3864)	accu 46.875 (45.493)
# Epoch-3   280 batches	loss 2.3501 (2.3872)	accu 45.312 (45.435)
# Epoch-3   300 batches	loss 2.3398 (2.3854)	accu 48.438 (45.438)
# Epoch-3   320 batches	loss 2.3228 (2.3809)	accu 50.000 (45.542)
# Epoch-3   340 batches	loss 2.3653 (2.3734)	accu 50.000 (45.915)
# Epoch-3   360 batches	loss 2.2336 (2.3704)	accu 51.562 (46.037)
# Epoch-3   380 batches	loss 2.3173 (2.3669)	accu 50.000 (46.180)
# Epoch-3   400 batches	loss 2.3855 (2.3655)	accu 37.500 (46.152)
# Epoch-3   420 batches	loss 2.1944 (2.3630)	accu 56.250 (46.250)
# Epoch-3   440 batches	loss 2.6000 (2.3611)	accu 35.938 (46.300)
# Epoch-3   460 batches	loss 2.2225 (2.3572)	accu 53.125 (46.359)
# Epoch-3   480 batches	loss 2.1865 (2.3584)	accu 53.125 (46.315)
# Epoch-3   500 batches	loss 2.4625 (2.3577)	accu 40.625 (46.331)
# Epoch-3   520 batches	loss 2.3483 (2.3579)	accu 56.250 (46.364)
# Epoch-3   540 batches	loss 2.1407 (2.3532)	accu 59.375 (46.548)
# Epoch-3   560 batches	loss 2.1095 (2.3536)	accu 57.812 (46.574)
# Epoch-3   580 batches	loss 2.3246 (2.3509)	accu 48.438 (46.676)
# Epoch-3   600 batches	loss 2.3374 (2.3484)	accu 43.750 (46.784)
# Epoch-3   620 batches	loss 2.4430 (2.3473)	accu 46.875 (46.802)
# Epoch-3   640 batches	loss 2.1660 (2.3460)	accu 57.812 (46.858)
# Epoch-3   660 batches	loss 2.2335 (2.3433)	accu 53.125 (46.965)
# Epoch-3   680 batches	loss 2.1493 (2.3417)	accu 59.375 (47.036)
# Epoch-3   700 batches	loss 2.4012 (2.3399)	accu 39.062 (47.080)
# Epoch-3   720 batches	loss 2.2570 (2.3376)	accu 45.312 (47.140)
# Epoch-3   740 batches	loss 2.1681 (2.3347)	accu 48.438 (47.198)
# Epoch-3   760 batches	loss 2.2403 (2.3323)	accu 45.312 (47.296)
# Epoch-3   780 batches	loss 2.3046 (2.3311)	accu 50.000 (47.294)
# Epoch-3   800 batches	loss 2.3871 (2.3306)	accu 42.188 (47.338)
# Epoch-3   820 batches	loss 2.3018 (2.3284)	accu 51.562 (47.407)
# Epoch-3   840 batches	loss 2.1173 (2.3264)	accu 54.688 (47.442)
# Epoch-3   860 batches	loss 1.9409 (2.3241)	accu 59.375 (47.531)
# Epoch-3   880 batches	loss 2.2256 (2.3236)	accu 48.438 (47.578)
# Epoch-3   900 batches	loss 2.1186 (2.3224)	accu 53.125 (47.602)
# Epoch-3   920 batches	loss 2.2338 (2.3200)	accu 48.438 (47.670)
# Epoch-3   940 batches	loss 1.9889 (2.3161)	accu 60.938 (47.822)
# Epoch-3   960 batches	loss 2.1971 (2.3144)	accu 54.688 (47.920)
# Epoch-3   980 batches	loss 2.1686 (2.3117)	accu 56.250 (48.023)
# Epoch-3   1000 batches	loss 2.0552 (2.3104)	accu 53.125 (48.066)
# Epoch-3   1020 batches	loss 2.0482 (2.3095)	accu 56.250 (48.084)
# Epoch-3   1040 batches	loss 2.4309 (2.3080)	accu 42.188 (48.154)
# Epoch-3   1060 batches	loss 2.2177 (2.3071)	accu 48.438 (48.196)
# Epoch-3   1080 batches	loss 2.5527 (2.3062)	accu 46.875 (48.229)
# Epoch-3   1100 batches	loss 2.0811 (2.3035)	accu 54.688 (48.325)
# Epoch-3   1120 batches	loss 2.3000 (2.3022)	accu 54.688 (48.351)
# Epoch-3   1140 batches	loss 2.3495 (2.3010)	accu 45.312 (48.384)
# Epoch-3   1160 batches	loss 2.3356 (2.3003)	accu 45.312 (48.408)
# Epoch-3   1180 batches	loss 2.3101 (2.2983)	accu 53.125 (48.497)
# Epoch-3   1200 batches	loss 2.2329 (2.2954)	accu 53.125 (48.612)
# Epoch-3   1220 batches	loss 2.0480 (2.2937)	accu 56.250 (48.660)
# Epoch-3   251.5s	Train: loss 2.2924	accu 48.7070	Valid: loss 1.9674	accu 61.0618
# Epoch 3: val_acc improved from 51.5329 to 61.0618, saving model to ./results/NTU/SGN\2_best.pth
# 3 0.001
# Epoch-4    20 batches	loss 2.2609 (2.1577)	accu 46.875 (53.125)
# Epoch-4    40 batches	loss 2.1553 (2.1611)	accu 53.125 (53.750)
# Epoch-4    60 batches	loss 2.2430 (2.1733)	accu 50.000 (53.542)
# Epoch-4    80 batches	loss 1.6856 (2.1740)	accu 71.875 (53.379)
# Epoch-4   100 batches	loss 2.2481 (2.1717)	accu 51.562 (53.359)
# Epoch-4   120 batches	loss 2.2376 (2.1627)	accu 56.250 (53.516)
# Epoch-4   140 batches	loss 2.3183 (2.1557)	accu 45.312 (53.683)
# Epoch-4   160 batches	loss 2.3860 (2.1551)	accu 37.500 (53.711)
# Epoch-4   180 batches	loss 2.1404 (2.1491)	accu 46.875 (53.819)
# Epoch-4   200 batches	loss 2.2316 (2.1475)	accu 48.438 (53.969)
# Epoch-4   220 batches	loss 2.0927 (2.1427)	accu 43.750 (54.077)
# Epoch-4   240 batches	loss 2.1479 (2.1408)	accu 51.562 (54.089)
# Epoch-4   260 batches	loss 2.4177 (2.1386)	accu 54.688 (54.267)
# Epoch-4   280 batches	loss 2.1673 (2.1367)	accu 48.438 (54.235)
# Epoch-4   300 batches	loss 2.3463 (2.1367)	accu 46.875 (54.292)
# Epoch-4   320 batches	loss 2.2218 (2.1376)	accu 54.688 (54.292)
# Epoch-4   340 batches	loss 2.1314 (2.1368)	accu 57.812 (54.370)
# Epoch-4   360 batches	loss 2.1133 (2.1375)	accu 48.438 (54.353)
# Epoch-4   380 batches	loss 2.1470 (2.1356)	accu 53.125 (54.404)
# Epoch-4   400 batches	loss 2.2445 (2.1358)	accu 50.000 (54.410)
# Epoch-4   420 batches	loss 2.0783 (2.1333)	accu 54.688 (54.531)
# Epoch-4   440 batches	loss 2.1836 (2.1312)	accu 57.812 (54.663)
# Epoch-4   460 batches	loss 2.0349 (2.1301)	accu 59.375 (54.681)
# Epoch-4   480 batches	loss 2.3115 (2.1288)	accu 42.188 (54.723)
# Epoch-4   500 batches	loss 2.1871 (2.1269)	accu 50.000 (54.809)
# Epoch-4   520 batches	loss 2.3587 (2.1271)	accu 40.625 (54.763)
# Epoch-4   540 batches	loss 2.3468 (2.1269)	accu 48.438 (54.786)
# Epoch-4   560 batches	loss 2.1208 (2.1273)	accu 48.438 (54.788)
# Epoch-4   580 batches	loss 1.9671 (2.1272)	accu 56.250 (54.833)
# Epoch-4   600 batches	loss 2.1604 (2.1255)	accu 57.812 (54.938)
# Epoch-4   620 batches	loss 1.9942 (2.1252)	accu 60.938 (54.962)
# Epoch-4   640 batches	loss 2.2077 (2.1252)	accu 48.438 (54.968)
# Epoch-4   660 batches	loss 2.2600 (2.1248)	accu 50.000 (54.972)
# Epoch-4   680 batches	loss 1.9332 (2.1220)	accu 56.250 (55.085)
# Epoch-4   700 batches	loss 2.1550 (2.1213)	accu 54.688 (55.132)
# Epoch-4   720 batches	loss 2.1631 (2.1201)	accu 45.312 (55.128)
# Epoch-4   740 batches	loss 2.1508 (2.1198)	accu 60.938 (55.131)
# Epoch-4   760 batches	loss 1.8643 (2.1180)	accu 65.625 (55.206)
# Epoch-4   780 batches	loss 2.0025 (2.1162)	accu 59.375 (55.246)
# Epoch-4   800 batches	loss 2.0379 (2.1144)	accu 56.250 (55.355)
# Epoch-4   820 batches	loss 1.9747 (2.1121)	accu 56.250 (55.431)
# Epoch-4   840 batches	loss 1.8692 (2.1101)	accu 60.938 (55.525)
# Epoch-4   860 batches	loss 2.0209 (2.1088)	accu 59.375 (55.581)
# Epoch-4   880 batches	loss 2.0753 (2.1079)	accu 51.562 (55.572)
# Epoch-4   900 batches	loss 2.0026 (2.1070)	accu 64.062 (55.623)
# Epoch-4   920 batches	loss 1.9216 (2.1050)	accu 65.625 (55.669)
# Epoch-4   940 batches	loss 2.0054 (2.1049)	accu 64.062 (55.672)
# Epoch-4   960 batches	loss 2.0284 (2.1035)	accu 59.375 (55.732)
# Epoch-4   980 batches	loss 1.9254 (2.1024)	accu 62.500 (55.765)
# Epoch-4   1000 batches	loss 2.2252 (2.1023)	accu 45.312 (55.758)
# Epoch-4   1020 batches	loss 2.3294 (2.1021)	accu 43.750 (55.757)
# Epoch-4   1040 batches	loss 2.1415 (2.1008)	accu 50.000 (55.822)
# Epoch-4   1060 batches	loss 2.2337 (2.1008)	accu 54.688 (55.802)
# Epoch-4   1080 batches	loss 2.3460 (2.1000)	accu 46.875 (55.830)
# Epoch-4   1100 batches	loss 1.9376 (2.0992)	accu 60.938 (55.866)
# Epoch-4   1120 batches	loss 2.0542 (2.0987)	accu 57.812 (55.900)
# Epoch-4   1140 batches	loss 2.1015 (2.0993)	accu 51.562 (55.868)
# Epoch-4   1160 batches	loss 1.9905 (2.0976)	accu 54.688 (55.924)
# Epoch-4   1180 batches	loss 2.1118 (2.0965)	accu 59.375 (55.979)
# Epoch-4   1200 batches	loss 2.0132 (2.0957)	accu 59.375 (56.027)
# Epoch-4   1220 batches	loss 1.9071 (2.0939)	accu 64.062 (56.078)
# Epoch-4   245.8s	Train: loss 2.0933	accu 56.1209	Valid: loss 1.8003	accu 67.4479
# Epoch 4: val_acc improved from 61.0618 to 67.4479, saving model to ./results/NTU/SGN\2_best.pth
# 4 0.001
# Epoch-5    20 batches	loss 1.8710 (1.9298)	accu 57.812 (63.203)
# Epoch-5    40 batches	loss 1.9548 (1.9431)	accu 54.688 (61.328)
# Epoch-5    60 batches	loss 1.9580 (1.9578)	accu 57.812 (60.755)
# Epoch-5    80 batches	loss 2.0665 (1.9562)	accu 56.250 (60.957)
# Epoch-5   100 batches	loss 2.1233 (1.9690)	accu 57.812 (60.484)
# Epoch-5   120 batches	loss 2.1654 (1.9802)	accu 53.125 (60.143)
# Epoch-5   140 batches	loss 1.8967 (1.9839)	accu 60.938 (60.045)
# Epoch-5   160 batches	loss 2.1109 (1.9842)	accu 64.062 (60.137)
# Epoch-5   180 batches	loss 1.9780 (1.9838)	accu 57.812 (60.148)
# Epoch-5   200 batches	loss 2.0054 (1.9916)	accu 56.250 (59.812)
# Epoch-5   220 batches	loss 2.1020 (1.9888)	accu 51.562 (60.085)
# Epoch-5   240 batches	loss 1.9203 (1.9884)	accu 62.500 (60.052)
# Epoch-5   260 batches	loss 1.9959 (1.9869)	accu 62.500 (60.072)
# Epoch-5   280 batches	loss 1.8834 (1.9869)	accu 64.062 (60.100)
# Epoch-5   300 batches	loss 2.0714 (1.9849)	accu 59.375 (60.193)
# Epoch-5   320 batches	loss 1.9410 (1.9884)	accu 62.500 (60.112)
# Epoch-5   340 batches	loss 1.8880 (1.9869)	accu 65.625 (60.184)
# Epoch-5   360 batches	loss 1.9780 (1.9863)	accu 62.500 (60.156)
# Epoch-5   380 batches	loss 1.8791 (1.9866)	accu 65.625 (60.070)
# Epoch-5   400 batches	loss 1.9057 (1.9866)	accu 60.938 (60.055)
# Epoch-5   420 batches	loss 2.2384 (1.9877)	accu 51.562 (60.045)
# Epoch-5   440 batches	loss 2.0400 (1.9872)	accu 54.688 (59.986)
# Epoch-5   460 batches	loss 2.0984 (1.9861)	accu 54.688 (60.027)
# Epoch-5   480 batches	loss 1.8178 (1.9872)	accu 59.375 (59.984)
# Epoch-5   500 batches	loss 1.8217 (1.9869)	accu 65.625 (60.003)
# Epoch-5   520 batches	loss 1.7685 (1.9847)	accu 68.750 (60.135)
# Epoch-5   540 batches	loss 1.9259 (1.9821)	accu 62.500 (60.243)
# Epoch-5   560 batches	loss 1.8117 (1.9780)	accu 59.375 (60.338)
# Epoch-5   580 batches	loss 2.0109 (1.9774)	accu 59.375 (60.366)
# Epoch-5   600 batches	loss 2.2738 (1.9782)	accu 51.562 (60.341)
# Epoch-5   620 batches	loss 1.9265 (1.9788)	accu 71.875 (60.272)
# Epoch-5   640 batches	loss 1.9627 (1.9781)	accu 64.062 (60.298)
# Epoch-5   660 batches	loss 2.2320 (1.9792)	accu 54.688 (60.241)
# Epoch-5   680 batches	loss 2.0416 (1.9794)	accu 60.938 (60.239)
# Epoch-5   700 batches	loss 1.9475 (1.9777)	accu 64.062 (60.310)
# Epoch-5   720 batches	loss 1.9951 (1.9779)	accu 59.375 (60.310)
# Epoch-5   740 batches	loss 2.0020 (1.9763)	accu 60.938 (60.342)
# Epoch-5   760 batches	loss 2.3625 (1.9768)	accu 51.562 (60.372)
# Epoch-5   780 batches	loss 1.8570 (1.9759)	accu 70.312 (60.389)
# Epoch-5   800 batches	loss 1.9949 (1.9759)	accu 53.125 (60.383)
# Epoch-5   820 batches	loss 1.9173 (1.9746)	accu 59.375 (60.448)
# Epoch-5   840 batches	loss 1.9537 (1.9731)	accu 59.375 (60.513)
# Epoch-5   860 batches	loss 1.6780 (1.9724)	accu 75.000 (60.556)
# Epoch-5   880 batches	loss 1.8101 (1.9721)	accu 64.062 (60.570)
# Epoch-5   900 batches	loss 1.8297 (1.9712)	accu 65.625 (60.582)
# Epoch-5   920 batches	loss 1.7453 (1.9704)	accu 70.312 (60.618)
# Epoch-5   940 batches	loss 1.7589 (1.9693)	accu 68.750 (60.665)
# Epoch-5   960 batches	loss 2.0055 (1.9677)	accu 54.688 (60.729)
# Epoch-5   980 batches	loss 1.9171 (1.9664)	accu 70.312 (60.799)
# Epoch-5   1000 batches	loss 1.9405 (1.9651)	accu 53.125 (60.858)
# Epoch-5   1020 batches	loss 1.9217 (1.9651)	accu 60.938 (60.846)
# Epoch-5   1040 batches	loss 1.8232 (1.9654)	accu 68.750 (60.840)
# Epoch-5   1060 batches	loss 1.7573 (1.9661)	accu 70.312 (60.833)
# Epoch-5   1080 batches	loss 1.8994 (1.9656)	accu 64.062 (60.865)
# Epoch-5   1100 batches	loss 1.8235 (1.9647)	accu 62.500 (60.903)
# Epoch-5   1120 batches	loss 1.9669 (1.9637)	accu 64.062 (60.914)
# Epoch-5   1140 batches	loss 2.0151 (1.9632)	accu 60.938 (60.940)
# Epoch-5   1160 batches	loss 1.9194 (1.9634)	accu 62.500 (60.942)
# Epoch-5   1180 batches	loss 1.8703 (1.9618)	accu 62.500 (61.005)
# Epoch-5   1200 batches	loss 1.9034 (1.9608)	accu 64.062 (61.052)
# Epoch-5   1220 batches	loss 1.9483 (1.9600)	accu 62.500 (61.089)
# Epoch-5   255.3s	Train: loss 1.9595	accu 61.1235	Valid: loss 1.7309	accu 70.4486
# Epoch 5: val_acc improved from 67.4479 to 70.4486, saving model to ./results/NTU/SGN\2_best.pth
# 5 0.001
# Epoch-6    20 batches	loss 1.7045 (1.8739)	accu 68.750 (64.375)
# Epoch-6    40 batches	loss 1.7227 (1.8723)	accu 67.188 (64.102)
# Epoch-6    60 batches	loss 1.8555 (1.8739)	accu 60.938 (63.880)
# Epoch-6    80 batches	loss 1.7759 (1.8689)	accu 65.625 (64.375)
# Epoch-6   100 batches	loss 1.6744 (1.8706)	accu 73.438 (64.438)
# Epoch-6   120 batches	loss 1.9534 (1.8742)	accu 56.250 (64.219)
# Epoch-6   140 batches	loss 2.3041 (1.8773)	accu 53.125 (64.085)
# Epoch-6   160 batches	loss 1.9766 (1.8799)	accu 67.188 (64.160)
# Epoch-6   180 batches	loss 1.7361 (1.8729)	accu 71.875 (64.340)
# Epoch-6   200 batches	loss 1.9250 (1.8718)	accu 70.312 (64.438)
# Epoch-6   220 batches	loss 2.0223 (1.8702)	accu 56.250 (64.545)
# Epoch-6   240 batches	loss 1.9824 (1.8693)	accu 62.500 (64.674)
# Epoch-6   260 batches	loss 1.7705 (1.8684)	accu 64.062 (64.748)
# Epoch-6   280 batches	loss 1.8198 (1.8680)	accu 65.625 (64.721)
# Epoch-6   300 batches	loss 1.7452 (1.8674)	accu 68.750 (64.688)
# Epoch-6   320 batches	loss 2.0075 (1.8703)	accu 57.812 (64.604)
# Epoch-6   340 batches	loss 1.6347 (1.8683)	accu 76.562 (64.651)
# Epoch-6   360 batches	loss 1.8738 (1.8677)	accu 64.062 (64.583)
# Epoch-6   380 batches	loss 1.7178 (1.8709)	accu 68.750 (64.416)
# Epoch-6   400 batches	loss 1.8948 (1.8721)	accu 67.188 (64.406)
# Epoch-6   420 batches	loss 2.1945 (1.8740)	accu 57.812 (64.338)
# Epoch-6   440 batches	loss 1.7557 (1.8748)	accu 73.438 (64.308)
# Epoch-6   460 batches	loss 1.8848 (1.8748)	accu 57.812 (64.293)
# Epoch-6   480 batches	loss 1.6473 (1.8746)	accu 70.312 (64.336)
# Epoch-6   500 batches	loss 2.0994 (1.8755)	accu 57.812 (64.303)
# Epoch-6   520 batches	loss 1.9872 (1.8755)	accu 65.625 (64.315)
# Epoch-6   540 batches	loss 1.7249 (1.8741)	accu 75.000 (64.384)
# Epoch-6   560 batches	loss 1.7894 (1.8741)	accu 64.062 (64.434)
# Epoch-6   580 batches	loss 1.8408 (1.8723)	accu 70.312 (64.488)
# Epoch-6   600 batches	loss 1.8805 (1.8714)	accu 62.500 (64.505)
# Epoch-6   620 batches	loss 1.7585 (1.8707)	accu 65.625 (64.559)
# Epoch-6   640 batches	loss 1.7283 (1.8687)	accu 76.562 (64.661)
# Epoch-6   660 batches	loss 1.7590 (1.8681)	accu 70.312 (64.683)
# Epoch-6   680 batches	loss 1.8659 (1.8680)	accu 67.188 (64.690)
# Epoch-6   700 batches	loss 1.7347 (1.8677)	accu 73.438 (64.685)
# Epoch-6   720 batches	loss 1.8095 (1.8681)	accu 67.188 (64.642)
# Epoch-6   740 batches	loss 1.8116 (1.8681)	accu 71.875 (64.662)
# Epoch-6   760 batches	loss 1.8528 (1.8665)	accu 64.062 (64.741)
# Epoch-6   780 batches	loss 1.9576 (1.8665)	accu 62.500 (64.732)
# Epoch-6   800 batches	loss 1.8253 (1.8653)	accu 70.312 (64.777)
# Epoch-6   820 batches	loss 1.8717 (1.8649)	accu 65.625 (64.785)
# Epoch-6   840 batches	loss 1.8515 (1.8648)	accu 68.750 (64.795)
# Epoch-6   860 batches	loss 1.8399 (1.8648)	accu 65.625 (64.804)
# Epoch-6   880 batches	loss 1.8565 (1.8652)	accu 62.500 (64.773)
# Epoch-6   900 batches	loss 1.7488 (1.8655)	accu 68.750 (64.790)
# Epoch-6   920 batches	loss 1.8181 (1.8642)	accu 65.625 (64.835)
# Epoch-6   940 batches	loss 1.7560 (1.8635)	accu 73.438 (64.870)
# Epoch-6   960 batches	loss 1.8139 (1.8624)	accu 65.625 (64.932)
# Epoch-6   980 batches	loss 1.9370 (1.8616)	accu 62.500 (64.963)
# Epoch-6   1000 batches	loss 1.9081 (1.8611)	accu 65.625 (64.980)
# Epoch-6   1020 batches	loss 2.0151 (1.8613)	accu 54.688 (64.957)
# Epoch-6   1040 batches	loss 1.9168 (1.8612)	accu 59.375 (64.964)
# Epoch-6   1060 batches	loss 1.9702 (1.8626)	accu 56.250 (64.892)
# Epoch-6   1080 batches	loss 2.0986 (1.8629)	accu 57.812 (64.905)
# Epoch-6   1100 batches	loss 2.0181 (1.8618)	accu 53.125 (64.942)
# Epoch-6   1120 batches	loss 1.7199 (1.8613)	accu 64.062 (64.946)
# Epoch-6   1140 batches	loss 1.7590 (1.8608)	accu 70.312 (64.971)
# Epoch-6   1160 batches	loss 1.6968 (1.8599)	accu 75.000 (64.995)
# Epoch-6   1180 batches	loss 1.9349 (1.8602)	accu 59.375 (64.977)
# Epoch-6   1200 batches	loss 2.0573 (1.8599)	accu 53.125 (64.982)
# Epoch-6   1220 batches	loss 1.6854 (1.8589)	accu 71.875 (65.022)
# Epoch-6   255.4s	Train: loss 1.8588	accu 65.0342	Valid: loss 1.6021	accu 75.6570
# Epoch 6: val_acc improved from 70.4486 to 75.6570, saving model to ./results/NTU/SGN\2_best.pth
# 6 0.001
# Epoch-7    20 batches	loss 1.9406 (1.7802)	accu 56.250 (67.969)
# Epoch-7    40 batches	loss 1.6813 (1.7538)	accu 68.750 (68.203)
# Epoch-7    60 batches	loss 1.8578 (1.7674)	accu 67.188 (67.760)
# Epoch-7    80 batches	loss 1.8584 (1.7662)	accu 62.500 (67.793)
# Epoch-7   100 batches	loss 1.7726 (1.7724)	accu 73.438 (67.719)
# Epoch-7   120 batches	loss 2.0043 (1.7787)	accu 59.375 (67.656)
# Epoch-7   140 batches	loss 1.9400 (1.7745)	accu 59.375 (67.902)
# Epoch-7   160 batches	loss 1.8278 (1.7738)	accu 68.750 (67.910)
# Epoch-7   180 batches	loss 1.7115 (1.7770)	accu 67.188 (67.847)
# Epoch-7   200 batches	loss 1.9143 (1.7874)	accu 62.500 (67.383)
# Epoch-7   220 batches	loss 1.6090 (1.7930)	accu 75.000 (67.330)
# Epoch-7   240 batches	loss 2.0818 (1.8000)	accu 56.250 (67.096)
# Epoch-7   260 batches	loss 1.7720 (1.8021)	accu 70.312 (67.079)
# Epoch-7   280 batches	loss 1.7373 (1.8079)	accu 73.438 (66.752)
# Epoch-7   300 batches	loss 1.8617 (1.8093)	accu 67.188 (66.646)
# Epoch-7   320 batches	loss 1.7245 (1.8038)	accu 75.000 (66.875)
# Epoch-7   340 batches	loss 1.6583 (1.8008)	accu 71.875 (66.967)
# Epoch-7   360 batches	loss 1.7184 (1.7970)	accu 67.188 (67.083)
# Epoch-7   380 batches	loss 2.0147 (1.7978)	accu 62.500 (67.097)
# Epoch-7   400 batches	loss 2.1697 (1.7992)	accu 51.562 (66.984)
# Epoch-7   420 batches	loss 1.5486 (1.7987)	accu 75.000 (67.072)
# Epoch-7   440 batches	loss 1.8662 (1.7991)	accu 59.375 (67.106)
# Epoch-7   460 batches	loss 1.8156 (1.7998)	accu 64.062 (67.035)
# Epoch-7   480 batches	loss 1.9776 (1.8002)	accu 53.125 (66.995)
# Epoch-7   500 batches	loss 1.6791 (1.7979)	accu 76.562 (67.147)
# Epoch-7   520 batches	loss 1.7743 (1.8006)	accu 65.625 (67.067)
# Epoch-7   540 batches	loss 1.5945 (1.7995)	accu 70.312 (67.052)
# Epoch-7   560 batches	loss 1.7499 (1.7989)	accu 73.438 (67.042)
# Epoch-7   580 batches	loss 1.5562 (1.7971)	accu 73.438 (67.134)
# Epoch-7   600 batches	loss 1.8962 (1.7961)	accu 64.062 (67.185)
# Epoch-7   620 batches	loss 2.0409 (1.7964)	accu 56.250 (67.177)
# Epoch-7   640 batches	loss 1.8038 (1.7975)	accu 67.188 (67.144)
# Epoch-7   660 batches	loss 1.8098 (1.7975)	accu 67.188 (67.131)
# Epoch-7   680 batches	loss 1.6513 (1.7963)	accu 75.000 (67.169)
# Epoch-7   700 batches	loss 1.6609 (1.7956)	accu 73.438 (67.225)
# Epoch-7   720 batches	loss 1.9100 (1.7961)	accu 67.188 (67.194)
# Epoch-7   740 batches	loss 1.6385 (1.7962)	accu 65.625 (67.179)
# Epoch-7   760 batches	loss 1.9381 (1.7955)	accu 59.375 (67.185)
# Epoch-7   780 batches	loss 1.8921 (1.7949)	accu 64.062 (67.234)
# Epoch-7   800 batches	loss 1.8400 (1.7955)	accu 60.938 (67.211)
# Epoch-7   820 batches	loss 1.9482 (1.7951)	accu 65.625 (67.226)
# Epoch-7   840 batches	loss 1.9198 (1.7936)	accu 65.625 (67.307)
# Epoch-7   860 batches	loss 1.9319 (1.7939)	accu 64.062 (67.295)
# Epoch-7   880 batches	loss 1.6164 (1.7926)	accu 73.438 (67.331)
# Epoch-7   900 batches	loss 1.6229 (1.7913)	accu 75.000 (67.403)
# Epoch-7   920 batches	loss 1.6667 (1.7904)	accu 76.562 (67.435)
# Epoch-7   940 batches	loss 1.5469 (1.7907)	accu 78.125 (67.422)
# Epoch-7   960 batches	loss 2.1644 (1.7909)	accu 51.562 (67.399)
# Epoch-7   980 batches	loss 1.5236 (1.7905)	accu 75.000 (67.385)
# Epoch-7   1000 batches	loss 1.6819 (1.7907)	accu 71.875 (67.377)
# Epoch-7   1020 batches	loss 1.6593 (1.7907)	accu 71.875 (67.365)
# Epoch-7   1040 batches	loss 1.8191 (1.7906)	accu 64.062 (67.371)
# Epoch-7   1060 batches	loss 1.8830 (1.7909)	accu 70.312 (67.325)
# Epoch-7   1080 batches	loss 1.9701 (1.7909)	accu 57.812 (67.287)
# Epoch-7   1100 batches	loss 1.6470 (1.7903)	accu 76.562 (67.352)
# Epoch-7   1120 batches	loss 1.7663 (1.7895)	accu 65.625 (67.384)
# Epoch-7   1140 batches	loss 1.6918 (1.7890)	accu 68.750 (67.404)
# Epoch-7   1160 batches	loss 1.5419 (1.7888)	accu 79.688 (67.406)
# Epoch-7   1180 batches	loss 1.7597 (1.7884)	accu 60.938 (67.419)
# Epoch-7   1200 batches	loss 2.0619 (1.7880)	accu 59.375 (67.445)
# Epoch-7   1220 batches	loss 1.9558 (1.7881)	accu 59.375 (67.445)
# Epoch-7   272.4s	Train: loss 1.7879	accu 67.4304	Valid: loss 1.5704	accu 76.7401
# Epoch 7: val_acc improved from 75.6570 to 76.7401, saving model to ./results/NTU/SGN\2_best.pth
# 7 0.001
# Epoch-8    20 batches	loss 1.6105 (1.7369)	accu 71.875 (69.609)
# Epoch-8    40 batches	loss 1.6914 (1.7185)	accu 70.312 (69.844)
# Epoch-8    60 batches	loss 1.5099 (1.7184)	accu 79.688 (69.401)
# Epoch-8    80 batches	loss 1.6216 (1.7054)	accu 68.750 (70.000)
# Epoch-8   100 batches	loss 1.7701 (1.6948)	accu 64.062 (70.547)
# Epoch-8   120 batches	loss 1.6527 (1.6995)	accu 71.875 (70.560)
# Epoch-8   140 batches	loss 1.7572 (1.7116)	accu 70.312 (70.145)
# Epoch-8   160 batches	loss 1.8267 (1.7127)	accu 64.062 (69.980)
# Epoch-8   180 batches	loss 1.8630 (1.7216)	accu 70.312 (69.670)
# Epoch-8   200 batches	loss 1.9878 (1.7272)	accu 65.625 (69.570)
# Epoch-8   220 batches	loss 1.4969 (1.7327)	accu 78.125 (69.375)
# Epoch-8   240 batches	loss 1.5451 (1.7297)	accu 71.875 (69.551)
# Epoch-8   260 batches	loss 1.6708 (1.7361)	accu 75.000 (69.321)
# Epoch-8   280 batches	loss 1.8786 (1.7367)	accu 70.312 (69.308)
# Epoch-8   300 batches	loss 1.6235 (1.7399)	accu 75.000 (69.229)
# Epoch-8   320 batches	loss 1.5521 (1.7406)	accu 75.000 (69.170)
# Epoch-8   340 batches	loss 1.5807 (1.7424)	accu 71.875 (69.127)
# Epoch-8   360 batches	loss 1.7149 (1.7458)	accu 71.875 (68.993)
# Epoch-8   380 batches	loss 1.7065 (1.7414)	accu 65.625 (69.120)
# Epoch-8   400 batches	loss 1.8248 (1.7381)	accu 60.938 (69.242)
# Epoch-8   420 batches	loss 1.6759 (1.7365)	accu 73.438 (69.338)
# Epoch-8   440 batches	loss 1.4605 (1.7357)	accu 73.438 (69.396)
# Epoch-8   460 batches	loss 1.8099 (1.7396)	accu 67.188 (69.243)
# Epoch-8   480 batches	loss 1.8607 (1.7415)	accu 68.750 (69.150)
# Epoch-8   500 batches	loss 1.6753 (1.7422)	accu 70.312 (69.134)
# Epoch-8   520 batches	loss 1.8163 (1.7426)	accu 65.625 (69.153)
# Epoch-8   540 batches	loss 1.8623 (1.7412)	accu 60.938 (69.222)
# Epoch-8   560 batches	loss 1.5569 (1.7384)	accu 81.250 (69.322)
# Epoch-8   580 batches	loss 1.5948 (1.7383)	accu 75.000 (69.356)
# Epoch-8   600 batches	loss 1.9815 (1.7385)	accu 56.250 (69.315)
# Epoch-8   620 batches	loss 1.8994 (1.7402)	accu 59.375 (69.264)
# Epoch-8   640 batches	loss 1.6400 (1.7394)	accu 75.000 (69.321)
# Epoch-8   660 batches	loss 1.6948 (1.7387)	accu 68.750 (69.342)
# Epoch-8   680 batches	loss 1.4940 (1.7382)	accu 81.250 (69.407)
# Epoch-8   700 batches	loss 1.8018 (1.7374)	accu 64.062 (69.467)
# Epoch-8   720 batches	loss 1.6809 (1.7377)	accu 70.312 (69.440)
# Epoch-8   740 batches	loss 1.5282 (1.7371)	accu 76.562 (69.468)
# Epoch-8   760 batches	loss 1.7867 (1.7378)	accu 68.750 (69.447)
# Epoch-8   780 batches	loss 1.7791 (1.7375)	accu 70.312 (69.503)
# Epoch-8   800 batches	loss 1.4939 (1.7370)	accu 79.688 (69.545)
# Epoch-8   820 batches	loss 1.5430 (1.7378)	accu 76.562 (69.493)
# Epoch-8   840 batches	loss 1.8435 (1.7380)	accu 68.750 (69.496)
# Epoch-8   860 batches	loss 1.5404 (1.7369)	accu 76.562 (69.539)
# Epoch-8   880 batches	loss 1.7847 (1.7371)	accu 62.500 (69.519)
# Epoch-8   900 batches	loss 1.9526 (1.7387)	accu 56.250 (69.417)
# Epoch-8   920 batches	loss 1.6375 (1.7390)	accu 64.062 (69.397)
# Epoch-8   940 batches	loss 1.9388 (1.7387)	accu 68.750 (69.412)
# Epoch-8   960 batches	loss 1.9072 (1.7384)	accu 59.375 (69.401)
# Epoch-8   980 batches	loss 1.8356 (1.7382)	accu 60.938 (69.405)
# Epoch-8   1000 batches	loss 1.7803 (1.7386)	accu 68.750 (69.394)
# Epoch-8   1020 batches	loss 1.6943 (1.7376)	accu 64.062 (69.412)
# Epoch-8   1040 batches	loss 1.5864 (1.7378)	accu 71.875 (69.410)
# Epoch-8   1060 batches	loss 1.7226 (1.7369)	accu 68.750 (69.443)
# Epoch-8   1080 batches	loss 1.6237 (1.7365)	accu 65.625 (69.491)
# Epoch-8   1100 batches	loss 1.7023 (1.7365)	accu 67.188 (69.469)
# Epoch-8   1120 batches	loss 1.6048 (1.7361)	accu 75.000 (69.480)
# Epoch-8   1140 batches	loss 2.0177 (1.7357)	accu 62.500 (69.515)
# Epoch-8   1160 batches	loss 1.7687 (1.7352)	accu 67.188 (69.535)
# Epoch-8   1180 batches	loss 1.5935 (1.7343)	accu 79.688 (69.567)
# Epoch-8   1200 batches	loss 1.7794 (1.7344)	accu 68.750 (69.557)
# Epoch-8   1220 batches	loss 1.5884 (1.7338)	accu 68.750 (69.580)
# Epoch-8   249.1s	Train: loss 1.7335	accu 69.5951	Valid: loss 1.5130	accu 78.7050
# Epoch 8: val_acc improved from 76.7401 to 78.7050, saving model to ./results/NTU/SGN\2_best.pth
# 8 0.001
# Epoch-9    20 batches	loss 1.6974 (1.6643)	accu 73.438 (71.641)
# Epoch-9    40 batches	loss 1.7278 (1.6810)	accu 68.750 (70.547)
# Epoch-9    60 batches	loss 2.1702 (1.6770)	accu 57.812 (71.276)
# Epoch-9    80 batches	loss 1.5577 (1.6751)	accu 78.125 (71.367)
# Epoch-9   100 batches	loss 1.5383 (1.6731)	accu 79.688 (71.719)
# Epoch-9   120 batches	loss 1.6857 (1.6769)	accu 73.438 (71.680)
# Epoch-9   140 batches	loss 1.6915 (1.6763)	accu 70.312 (71.830)
# Epoch-9   160 batches	loss 1.5988 (1.6787)	accu 76.562 (71.709)
# Epoch-9   180 batches	loss 1.6960 (1.6858)	accu 78.125 (71.354)
# Epoch-9   200 batches	loss 1.4966 (1.6823)	accu 81.250 (71.570)
# Epoch-9   220 batches	loss 1.6139 (1.6789)	accu 79.688 (71.626)
# Epoch-9   240 batches	loss 1.6345 (1.6777)	accu 70.312 (71.608)
# Epoch-9   260 batches	loss 1.9129 (1.6780)	accu 62.500 (71.599)
# Epoch-9   280 batches	loss 1.5855 (1.6778)	accu 75.000 (71.613)
# Epoch-9   300 batches	loss 1.8049 (1.6783)	accu 59.375 (71.568)
# Epoch-9   320 batches	loss 1.6109 (1.6791)	accu 70.312 (71.431)
# Epoch-9   340 batches	loss 1.7314 (1.6789)	accu 76.562 (71.415)
# Epoch-9   360 batches	loss 1.6125 (1.6794)	accu 71.875 (71.432)
# Epoch-9   380 batches	loss 1.8353 (1.6787)	accu 65.625 (71.414)
# Epoch-9   400 batches	loss 1.4999 (1.6775)	accu 78.125 (71.469)
# Epoch-9   420 batches	loss 1.8381 (1.6766)	accu 65.625 (71.551)
# Epoch-9   440 batches	loss 1.6609 (1.6754)	accu 68.750 (71.580)
# Epoch-9   460 batches	loss 1.6221 (1.6740)	accu 78.125 (71.685)
# Epoch-9   480 batches	loss 1.8635 (1.6731)	accu 68.750 (71.790)
# Epoch-9   500 batches	loss 1.4638 (1.6720)	accu 84.375 (71.869)
# Epoch-9   520 batches	loss 1.8244 (1.6726)	accu 57.812 (71.806)
# Epoch-9   540 batches	loss 2.0221 (1.6735)	accu 67.188 (71.797)
# Epoch-9   560 batches	loss 1.8750 (1.6734)	accu 60.938 (71.844)
# Epoch-9   580 batches	loss 1.7048 (1.6738)	accu 75.000 (71.818)
# Epoch-9   600 batches	loss 1.6629 (1.6733)	accu 68.750 (71.854)
# Epoch-9   620 batches	loss 1.9316 (1.6746)	accu 60.938 (71.759)
# Epoch-9   640 batches	loss 1.8558 (1.6743)	accu 64.062 (71.772)
# Epoch-9   660 batches	loss 1.5248 (1.6746)	accu 76.562 (71.771)
# Epoch-9   680 batches	loss 1.8637 (1.6741)	accu 65.625 (71.781)
# Epoch-9   700 batches	loss 1.6498 (1.6738)	accu 67.188 (71.766)
# Epoch-9   720 batches	loss 1.5975 (1.6748)	accu 71.875 (71.751)
# Epoch-9   740 batches	loss 1.8335 (1.6747)	accu 70.312 (71.721)
# Epoch-9   760 batches	loss 1.6279 (1.6743)	accu 75.000 (71.729)
# Epoch-9   780 batches	loss 1.5179 (1.6746)	accu 76.562 (71.729)
# Epoch-9   800 batches	loss 1.7469 (1.6760)	accu 71.875 (71.680)
# Epoch-9   820 batches	loss 1.5500 (1.6765)	accu 73.438 (71.637)
# Epoch-9   840 batches	loss 1.7147 (1.6777)	accu 76.562 (71.615)
# Epoch-9   860 batches	loss 1.7321 (1.6772)	accu 75.000 (71.648)
# Epoch-9   880 batches	loss 1.7036 (1.6778)	accu 73.438 (71.621)
# Epoch-9   900 batches	loss 1.6006 (1.6779)	accu 75.000 (71.649)
# Epoch-9   920 batches	loss 1.6904 (1.6785)	accu 73.438 (71.622)
# Epoch-9   940 batches	loss 1.3829 (1.6778)	accu 84.375 (71.652)
# Epoch-9   960 batches	loss 1.6836 (1.6779)	accu 71.875 (71.637)
# Epoch-9   980 batches	loss 1.8318 (1.6786)	accu 70.312 (71.645)
# Epoch-9   1000 batches	loss 1.6100 (1.6792)	accu 75.000 (71.617)
# Epoch-9   1020 batches	loss 1.6077 (1.6786)	accu 73.438 (71.667)
# Epoch-9   1040 batches	loss 2.0047 (1.6788)	accu 56.250 (71.630)
# Epoch-9   1060 batches	loss 1.5419 (1.6798)	accu 81.250 (71.602)
# Epoch-9   1080 batches	loss 1.5983 (1.6801)	accu 71.875 (71.576)
# Epoch-9   1100 batches	loss 1.7457 (1.6805)	accu 70.312 (71.574)
# Epoch-9   1120 batches	loss 1.6218 (1.6805)	accu 75.000 (71.560)
# Epoch-9   1140 batches	loss 1.6503 (1.6799)	accu 73.438 (71.561)
# Epoch-9   1160 batches	loss 1.5660 (1.6798)	accu 73.438 (71.584)
# Epoch-9   1180 batches	loss 1.6903 (1.6801)	accu 71.875 (71.598)
# Epoch-9   1200 batches	loss 1.5576 (1.6803)	accu 76.562 (71.566)
# Epoch-9   1220 batches	loss 1.4811 (1.6806)	accu 85.938 (71.548)
# Epoch-9   269.9s	Train: loss 1.6812	accu 71.5334	Valid: loss 1.4952	accu 79.0720
# Epoch 9: val_acc improved from 78.7050 to 79.0720, saving model to ./results/NTU/SGN\2_best.pth
# 9 0.001
# Epoch-10   20 batches	loss 1.9023 (1.6799)	accu 62.500 (72.031)
# Epoch-10   40 batches	loss 1.4840 (1.6803)	accu 75.000 (71.562)
# Epoch-10   60 batches	loss 1.4716 (1.6533)	accu 81.250 (72.656)
# Epoch-10   80 batches	loss 1.6677 (1.6388)	accu 73.438 (73.320)
# Epoch-10  100 batches	loss 1.5741 (1.6362)	accu 79.688 (73.500)
# Epoch-10  120 batches	loss 1.6806 (1.6349)	accu 70.312 (73.672)
# Epoch-10  140 batches	loss 1.6766 (1.6371)	accu 71.875 (73.594)
# Epoch-10  160 batches	loss 1.8644 (1.6397)	accu 68.750 (73.535)
# Epoch-10  180 batches	loss 1.5768 (1.6400)	accu 76.562 (73.325)
# Epoch-10  200 batches	loss 1.4869 (1.6356)	accu 78.125 (73.406)
# Epoch-10  220 batches	loss 1.7497 (1.6398)	accu 62.500 (73.303)
# Epoch-10  240 batches	loss 1.5031 (1.6429)	accu 79.688 (73.132)
# Epoch-10  260 batches	loss 1.6928 (1.6435)	accu 70.312 (73.227)
# Epoch-10  280 batches	loss 1.4683 (1.6475)	accu 81.250 (73.119)
# Epoch-10  300 batches	loss 1.5998 (1.6475)	accu 75.000 (73.120)
# Epoch-10  320 batches	loss 1.5323 (1.6492)	accu 75.000 (72.964)
# Epoch-10  340 batches	loss 1.5992 (1.6490)	accu 65.625 (72.973)
# Epoch-10  360 batches	loss 1.5606 (1.6489)	accu 75.000 (72.960)
# Epoch-10  380 batches	loss 1.7191 (1.6468)	accu 75.000 (73.088)
# Epoch-10  400 batches	loss 1.6994 (1.6469)	accu 68.750 (73.137)
# Epoch-10  420 batches	loss 1.5278 (1.6455)	accu 81.250 (73.192)
# Epoch-10  440 batches	loss 1.5186 (1.6434)	accu 81.250 (73.278)
# Epoch-10  460 batches	loss 1.8602 (1.6425)	accu 65.625 (73.329)
# Epoch-10  480 batches	loss 1.5900 (1.6425)	accu 73.438 (73.317)
# Epoch-10  500 batches	loss 1.6938 (1.6421)	accu 70.312 (73.322)
# Epoch-10  520 batches	loss 1.7819 (1.6433)	accu 68.750 (73.278)
# Epoch-10  540 batches	loss 1.6009 (1.6431)	accu 73.438 (73.229)
# Epoch-10  560 batches	loss 1.7019 (1.6418)	accu 71.875 (73.267)
# Epoch-10  580 batches	loss 1.4974 (1.6429)	accu 76.562 (73.209)
# Epoch-10  600 batches	loss 1.6796 (1.6436)	accu 75.000 (73.148)
# Epoch-10  620 batches	loss 1.5385 (1.6445)	accu 81.250 (73.125)
# Epoch-10  640 batches	loss 1.5333 (1.6439)	accu 78.125 (73.130)
# Epoch-10  660 batches	loss 1.6234 (1.6444)	accu 67.188 (73.071)
# Epoch-10  680 batches	loss 1.6527 (1.6437)	accu 70.312 (73.100)
# Epoch-10  700 batches	loss 1.6461 (1.6442)	accu 73.438 (73.076)
# Epoch-10  720 batches	loss 1.9600 (1.6442)	accu 62.500 (73.069)
# Epoch-10  740 batches	loss 1.7298 (1.6431)	accu 64.062 (73.121)
# Epoch-10  760 batches	loss 1.4619 (1.6410)	accu 79.688 (73.193)
# Epoch-10  780 batches	loss 1.6000 (1.6412)	accu 79.688 (73.165)
# Epoch-10  800 batches	loss 1.9453 (1.6427)	accu 64.062 (73.090)
# Epoch-10  820 batches	loss 1.7387 (1.6438)	accu 73.438 (73.043)
# Epoch-10  840 batches	loss 1.9440 (1.6452)	accu 62.500 (72.976)
# Epoch-10  860 batches	loss 1.5982 (1.6467)	accu 75.000 (72.903)
# Epoch-10  880 batches	loss 1.7299 (1.6466)	accu 64.062 (72.891)
# Epoch-10  900 batches	loss 1.4869 (1.6461)	accu 75.000 (72.925)
# Epoch-10  920 batches	loss 1.7606 (1.6454)	accu 65.625 (72.940)
# Epoch-10  940 batches	loss 1.4664 (1.6453)	accu 84.375 (72.919)
# Epoch-10  960 batches	loss 1.7733 (1.6450)	accu 70.312 (72.944)
# Epoch-10  980 batches	loss 1.8403 (1.6461)	accu 65.625 (72.913)
# Epoch-10  1000 batches	loss 1.7151 (1.6451)	accu 73.438 (72.966)
# Epoch-10  1020 batches	loss 1.6470 (1.6437)	accu 71.875 (73.007)
# Epoch-10  1040 batches	loss 1.6059 (1.6434)	accu 76.562 (73.024)
# Epoch-10  1060 batches	loss 1.7372 (1.6437)	accu 73.438 (73.013)
# Epoch-10  1080 batches	loss 1.5900 (1.6446)	accu 73.438 (72.998)
# Epoch-10  1100 batches	loss 1.6670 (1.6442)	accu 70.312 (73.013)
# Epoch-10  1120 batches	loss 1.6829 (1.6439)	accu 73.438 (73.008)
# Epoch-10  1140 batches	loss 1.6233 (1.6433)	accu 71.875 (73.037)
# Epoch-10  1160 batches	loss 1.7171 (1.6446)	accu 70.312 (72.986)
# Epoch-10  1180 batches	loss 1.7264 (1.6447)	accu 68.750 (72.970)
# Epoch-10  1200 batches	loss 1.5551 (1.6453)	accu 76.562 (72.932)
# Epoch-10  1220 batches	loss 1.6972 (1.6459)	accu 78.125 (72.906)
# Epoch-10  249.9s	Train: loss 1.6458	accu 72.9074	Valid: loss 1.4720	accu 80.2557
# Epoch 10: val_acc improved from 79.0720 to 80.2557, saving model to ./results/NTU/SGN\2_best.pth
# 10 0.001
# Epoch-11   20 batches	loss 1.7806 (1.6119)	accu 68.750 (74.844)
# Epoch-11   40 batches	loss 1.5700 (1.6030)	accu 75.000 (75.039)
# Epoch-11   60 batches	loss 1.8270 (1.6001)	accu 67.188 (75.417)
# Epoch-11   80 batches	loss 1.6307 (1.5960)	accu 71.875 (75.430)
# Epoch-11  100 batches	loss 1.3739 (1.5905)	accu 84.375 (75.609)
# Epoch-11  120 batches	loss 1.6435 (1.5958)	accu 73.438 (75.482)
# Epoch-11  140 batches	loss 1.5814 (1.5907)	accu 73.438 (75.670)
# Epoch-11  160 batches	loss 1.6070 (1.5877)	accu 76.562 (75.742)
# Epoch-11  180 batches	loss 1.5391 (1.5882)	accu 76.562 (75.773)
# Epoch-11  200 batches	loss 1.6997 (1.5886)	accu 65.625 (75.820)
# Epoch-11  220 batches	loss 1.4498 (1.5859)	accu 79.688 (75.874)
# Epoch-11  240 batches	loss 1.5856 (1.5881)	accu 73.438 (75.677)
# Epoch-11  260 batches	loss 1.5694 (1.5911)	accu 78.125 (75.661)
# Epoch-11  280 batches	loss 1.4709 (1.5955)	accu 81.250 (75.324)
# Epoch-11  300 batches	loss 1.3419 (1.5970)	accu 87.500 (75.214)
# Epoch-11  320 batches	loss 1.5329 (1.6009)	accu 78.125 (74.941)
# Epoch-11  340 batches	loss 1.6069 (1.6036)	accu 71.875 (74.825)
# Epoch-11  360 batches	loss 1.4246 (1.6049)	accu 81.250 (74.753)
# Epoch-11  380 batches	loss 1.5268 (1.6044)	accu 75.000 (74.700)
# Epoch-11  400 batches	loss 1.5943 (1.6066)	accu 79.688 (74.582)
# Epoch-11  420 batches	loss 1.6280 (1.6068)	accu 65.625 (74.513)
# Epoch-11  440 batches	loss 1.6201 (1.6066)	accu 70.312 (74.506)
# Epoch-11  460 batches	loss 1.7062 (1.6089)	accu 65.625 (74.419)
# Epoch-11  480 batches	loss 1.4466 (1.6091)	accu 76.562 (74.401)
# Epoch-11  500 batches	loss 1.4968 (1.6086)	accu 82.812 (74.459)
# Epoch-11  520 batches	loss 1.7761 (1.6096)	accu 73.438 (74.417)
# Epoch-11  540 batches	loss 1.7184 (1.6092)	accu 70.312 (74.418)
# Epoch-11  560 batches	loss 1.6036 (1.6083)	accu 76.562 (74.436)
# Epoch-11  580 batches	loss 1.7085 (1.6079)	accu 73.438 (74.426)
# Epoch-11  600 batches	loss 1.5642 (1.6086)	accu 73.438 (74.344)
# Epoch-11  620 batches	loss 1.7062 (1.6084)	accu 73.438 (74.345)
# Epoch-11  640 batches	loss 1.5165 (1.6081)	accu 79.688 (74.365)
# Epoch-11  660 batches	loss 1.4643 (1.6080)	accu 76.562 (74.354)
# Epoch-11  680 batches	loss 1.6223 (1.6079)	accu 70.312 (74.391)
# Epoch-11  700 batches	loss 1.6131 (1.6079)	accu 70.312 (74.411)
# Epoch-11  720 batches	loss 1.5818 (1.6076)	accu 78.125 (74.425)
# Epoch-11  740 batches	loss 1.5951 (1.6084)	accu 75.000 (74.390)
# Epoch-11  760 batches	loss 1.6189 (1.6089)	accu 71.875 (74.394)
# Epoch-11  780 batches	loss 1.5854 (1.6101)	accu 76.562 (74.377)
# Epoch-11  800 batches	loss 1.4780 (1.6095)	accu 78.125 (74.389)
# Epoch-11  820 batches	loss 1.5091 (1.6094)	accu 82.812 (74.415)
# Epoch-11  840 batches	loss 1.4396 (1.6096)	accu 79.688 (74.429)
# Epoch-11  860 batches	loss 1.6380 (1.6088)	accu 70.312 (74.442)
# Epoch-11  880 batches	loss 1.5356 (1.6085)	accu 81.250 (74.451)
# Epoch-11  900 batches	loss 1.5734 (1.6089)	accu 68.750 (74.401)
# Epoch-11  920 batches	loss 1.6322 (1.6090)	accu 70.312 (74.411)
# Epoch-11  940 batches	loss 1.4608 (1.6087)	accu 78.125 (74.425)
# Epoch-11  960 batches	loss 1.6253 (1.6088)	accu 71.875 (74.424)
# Epoch-11  980 batches	loss 1.7824 (1.6094)	accu 70.312 (74.428)
# Epoch-11  1000 batches	loss 1.4526 (1.6088)	accu 76.562 (74.441)
# Epoch-11  1020 batches	loss 1.6520 (1.6095)	accu 75.000 (74.421)
# Epoch-11  1040 batches	loss 1.4458 (1.6095)	accu 79.688 (74.423)
# Epoch-11  1060 batches	loss 1.5354 (1.6098)	accu 78.125 (74.438)
# Epoch-11  1080 batches	loss 1.4226 (1.6097)	accu 81.250 (74.437)
# Epoch-11  1100 batches	loss 1.5511 (1.6104)	accu 81.250 (74.385)
# Epoch-11  1120 batches	loss 1.4063 (1.6107)	accu 84.375 (74.372)
# Epoch-11  1140 batches	loss 1.8719 (1.6112)	accu 67.188 (74.360)
# Epoch-11  1160 batches	loss 1.3965 (1.6109)	accu 87.500 (74.383)
# Epoch-11  1180 batches	loss 1.8353 (1.6108)	accu 60.938 (74.390)
# Epoch-11  1200 batches	loss 1.5802 (1.6116)	accu 78.125 (74.370)
# Epoch-11  1220 batches	loss 1.6136 (1.6125)	accu 76.562 (74.337)
# Epoch-11  250.6s	Train: loss 1.6126	accu 74.3370	Valid: loss 1.4499	accu 81.1849
# Epoch 11: val_acc improved from 80.2557 to 81.1849, saving model to ./results/NTU/SGN\2_best.pth
# 11 0.001
# Epoch-12   20 batches	loss 1.5235 (1.5738)	accu 73.438 (75.391)
# Epoch-12   40 batches	loss 1.4137 (1.5652)	accu 82.812 (75.586)
# Epoch-12   60 batches	loss 1.5346 (1.5499)	accu 79.688 (75.990)
# Epoch-12   80 batches	loss 1.6487 (1.5674)	accu 78.125 (75.215)
# Epoch-12  100 batches	loss 1.6650 (1.5586)	accu 70.312 (75.781)
# Epoch-12  120 batches	loss 1.4030 (1.5598)	accu 84.375 (75.755)
# Epoch-12  140 batches	loss 1.8542 (1.5585)	accu 64.062 (75.915)
# Epoch-12  160 batches	loss 1.7092 (1.5584)	accu 67.188 (75.762)
# Epoch-12  180 batches	loss 1.7282 (1.5615)	accu 70.312 (75.616)
# Epoch-12  200 batches	loss 1.5238 (1.5652)	accu 76.562 (75.461)
# Epoch-12  220 batches	loss 1.7789 (1.5683)	accu 67.188 (75.447)
# Epoch-12  240 batches	loss 1.5914 (1.5690)	accu 76.562 (75.436)
# Epoch-12  260 batches	loss 1.7692 (1.5700)	accu 67.188 (75.427)
# Epoch-12  280 batches	loss 1.6310 (1.5715)	accu 68.750 (75.324)
# Epoch-12  300 batches	loss 1.5319 (1.5696)	accu 81.250 (75.479)
# Epoch-12  320 batches	loss 1.6109 (1.5705)	accu 78.125 (75.430)
# Epoch-12  340 batches	loss 1.5592 (1.5720)	accu 78.125 (75.414)
# Epoch-12  360 batches	loss 1.7436 (1.5716)	accu 71.875 (75.551)
# Epoch-12  380 batches	loss 1.6390 (1.5726)	accu 76.562 (75.530)
# Epoch-12  400 batches	loss 1.4002 (1.5723)	accu 79.688 (75.555)
# Epoch-12  420 batches	loss 1.7989 (1.5749)	accu 65.625 (75.435)
# Epoch-12  440 batches	loss 1.6079 (1.5743)	accu 75.000 (75.487)
# Epoch-12  460 batches	loss 1.5518 (1.5738)	accu 70.312 (75.469)
# Epoch-12  480 batches	loss 1.4453 (1.5727)	accu 76.562 (75.521)
# Epoch-12  500 batches	loss 1.4726 (1.5719)	accu 82.812 (75.591)
# Epoch-12  520 batches	loss 1.7051 (1.5716)	accu 70.312 (75.643)
# Epoch-12  540 batches	loss 1.5547 (1.5718)	accu 84.375 (75.645)
# Epoch-12  560 batches	loss 1.6049 (1.5720)	accu 70.312 (75.664)
# Epoch-12  580 batches	loss 1.3031 (1.5736)	accu 87.500 (75.609)
# Epoch-12  600 batches	loss 1.4741 (1.5726)	accu 82.812 (75.656)
# Epoch-12  620 batches	loss 1.6297 (1.5735)	accu 79.688 (75.625)
# Epoch-12  640 batches	loss 1.5071 (1.5744)	accu 81.250 (75.623)
# Epoch-12  660 batches	loss 1.4774 (1.5744)	accu 78.125 (75.623)
# Epoch-12  680 batches	loss 1.5022 (1.5741)	accu 81.250 (75.623)
# Epoch-12  700 batches	loss 1.5666 (1.5734)	accu 78.125 (75.679)
# Epoch-12  720 batches	loss 1.5268 (1.5733)	accu 76.562 (75.692)
# Epoch-12  740 batches	loss 1.4857 (1.5736)	accu 84.375 (75.712)
# Epoch-12  760 batches	loss 1.5570 (1.5738)	accu 70.312 (75.715)
# Epoch-12  780 batches	loss 1.6107 (1.5742)	accu 71.875 (75.659)
# Epoch-12  800 batches	loss 2.0061 (1.5743)	accu 51.562 (75.664)
# Epoch-12  820 batches	loss 1.6456 (1.5738)	accu 65.625 (75.688)
# Epoch-12  840 batches	loss 1.5501 (1.5751)	accu 78.125 (75.627)
# Epoch-12  860 batches	loss 1.6919 (1.5744)	accu 68.750 (75.643)
# ...
# Epoch-115 460 batches	loss 0.9987 (1.0006)	accu 96.875 (97.300)
# Epoch-115 480 batches	loss 0.9951 (1.0007)	accu 98.438 (97.282)
# Epoch-115 500 batches	loss 1.0043 (1.0005)	accu 96.875 (97.297)
# Epoch-115 520 batches	loss 0.9888 (1.0003)	accu 98.438 (97.308)
# Epoch-115 540 batches	loss 0.9853 (1.0001)	accu 100.000 (97.338)
# Epoch-115 560 batches	loss 0.9846 (1.0007)	accu 96.875 (97.291)
# Epoch-115 580 batches	loss 1.0324 (1.0013)	accu 93.750 (97.279)
# Epoch-115 600 batches	loss 1.0901 (1.0017)	accu 95.312 (97.279)
# Epoch-115 620 batches	loss 0.9853 (1.0014)	accu 96.875 (97.296)
# Epoch-115 640 batches	loss 0.9719 (1.0017)	accu 98.438 (97.302)
# Epoch-115 660 batches	loss 1.0634 (1.0019)	accu 93.750 (97.299)
# Epoch-115 680 batches	loss 0.9605 (1.0012)	accu 98.438 (97.305)
# Epoch-115 700 batches	loss 0.9927 (1.0019)	accu 98.438 (97.270)
# Epoch-115 720 batches	loss 1.0317 (1.0017)	accu 96.875 (97.279)
# Epoch-115 740 batches	loss 0.9933 (1.0013)	accu 98.438 (97.302)
# Epoch-115 760 batches	loss 1.0447 (1.0008)	accu 98.438 (97.325)
# Epoch-115 780 batches	loss 1.0586 (1.0009)	accu 98.438 (97.326)
# Epoch-115 800 batches	loss 1.0189 (1.0009)	accu 98.438 (97.348)
# Epoch-115 820 batches	loss 0.9966 (1.0006)	accu 98.438 (97.365)
# Epoch-115 840 batches	loss 1.0050 (1.0008)	accu 98.438 (97.344)
# Epoch-115 860 batches	loss 0.9286 (1.0005)	accu 100.000 (97.353)
# Epoch-115 880 batches	loss 0.9743 (1.0008)	accu 96.875 (97.347)
# Epoch-115 900 batches	loss 0.9722 (1.0010)	accu 98.438 (97.344)
# Epoch-115 920 batches	loss 0.9569 (1.0010)	accu 98.438 (97.345)
# Epoch-115 940 batches	loss 1.0123 (1.0013)	accu 96.875 (97.327)
# Epoch-115 960 batches	loss 0.9382 (1.0012)	accu 100.000 (97.334)
# Epoch-115 980 batches	loss 0.9734 (1.0012)	accu 98.438 (97.336)
# Epoch-115 1000 batches	loss 1.0960 (1.0016)	accu 96.875 (97.328)
# Epoch-115 1020 batches	loss 0.9577 (1.0016)	accu 100.000 (97.330)
# Epoch-115 1040 batches	loss 1.0577 (1.0015)	accu 95.312 (97.335)
# Epoch-115 1060 batches	loss 1.1125 (1.0016)	accu 90.625 (97.325)
# Epoch-115 1080 batches	loss 1.0109 (1.0020)	accu 98.438 (97.310)
# Epoch-115 1100 batches	loss 1.0125 (1.0022)	accu 98.438 (97.304)
# Epoch-115 1120 batches	loss 0.9517 (1.0019)	accu 98.438 (97.316)
# Epoch-115 1140 batches	loss 0.9910 (1.0018)	accu 100.000 (97.318)
# Epoch-115 1160 batches	loss 1.0130 (1.0015)	accu 96.875 (97.330)
# Epoch-115 1180 batches	loss 0.9691 (1.0017)	accu 100.000 (97.321)
# Epoch-115 1200 batches	loss 1.0422 (1.0015)	accu 93.750 (97.328)
# Epoch-115 1220 batches	loss 0.9481 (1.0014)	accu 100.000 (97.334)
# Epoch-115 258.3s	Train: loss 1.0014	accu 97.3317	Valid: loss 1.0538	accu 94.8804
# Epoch 115: val_acc did not improve
# 115 1.0000000000000002e-06
# Epoch-116  20 batches	loss 0.9416 (0.9880)	accu 98.438 (97.656)
# Epoch-116  40 batches	loss 1.0302 (0.9855)	accu 96.875 (97.969)
# Epoch-116  60 batches	loss 1.0547 (0.9906)	accu 96.875 (97.734)
# Epoch-116  80 batches	loss 0.9728 (0.9890)	accu 98.438 (97.715)
# Epoch-116 100 batches	loss 0.9784 (0.9944)	accu 98.438 (97.406)
# Epoch-116 120 batches	loss 1.0207 (0.9933)	accu 96.875 (97.435)
# Epoch-116 140 batches	loss 1.0720 (0.9937)	accu 93.750 (97.433)
# Epoch-116 160 batches	loss 0.9874 (0.9947)	accu 98.438 (97.422)
# Epoch-116 180 batches	loss 0.9562 (0.9942)	accu 98.438 (97.431)
# Epoch-116 200 batches	loss 1.0443 (0.9960)	accu 95.312 (97.375)
# Epoch-116 220 batches	loss 1.0121 (0.9975)	accu 98.438 (97.372)
# Epoch-116 240 batches	loss 1.0071 (0.9963)	accu 98.438 (97.441)
# Epoch-116 260 batches	loss 0.9609 (0.9962)	accu 100.000 (97.470)
# Epoch-116 280 batches	loss 0.9533 (0.9962)	accu 100.000 (97.450)
# Epoch-116 300 batches	loss 1.1074 (0.9965)	accu 93.750 (97.448)
# Epoch-116 320 batches	loss 0.9889 (0.9970)	accu 98.438 (97.441)
# Epoch-116 340 batches	loss 1.0182 (0.9967)	accu 96.875 (97.468)
# Epoch-116 360 batches	loss 0.9792 (0.9971)	accu 96.875 (97.457)
# Epoch-116 380 batches	loss 0.9365 (0.9979)	accu 98.438 (97.430)
# Epoch-116 400 batches	loss 1.1386 (0.9994)	accu 93.750 (97.406)
# Epoch-116 420 batches	loss 0.9859 (0.9987)	accu 96.875 (97.426)
# Epoch-116 440 batches	loss 0.9510 (0.9976)	accu 98.438 (97.472)
# Epoch-116 460 batches	loss 1.0606 (0.9980)	accu 96.875 (97.469)
# Epoch-116 480 batches	loss 0.9578 (0.9983)	accu 98.438 (97.454)
# Epoch-116 500 batches	loss 0.9782 (0.9982)	accu 96.875 (97.450)
# Epoch-116 520 batches	loss 1.0304 (0.9984)	accu 95.312 (97.437)
# Epoch-116 540 batches	loss 1.0674 (0.9986)	accu 95.312 (97.433)
# Epoch-116 560 batches	loss 0.9241 (0.9989)	accu 100.000 (97.425)
# Epoch-116 580 batches	loss 0.9860 (0.9982)	accu 100.000 (97.462)
# Epoch-116 600 batches	loss 1.0445 (0.9981)	accu 96.875 (97.469)
# Epoch-116 620 batches	loss 0.9557 (0.9985)	accu 98.438 (97.457)
# Epoch-116 640 batches	loss 0.9984 (0.9983)	accu 93.750 (97.478)
# Epoch-116 660 batches	loss 0.9867 (0.9982)	accu 98.438 (97.474)
# Epoch-116 680 batches	loss 0.9457 (0.9980)	accu 98.438 (97.484)
# Epoch-116 700 batches	loss 0.9845 (0.9986)	accu 96.875 (97.455)
# Epoch-116 720 batches	loss 1.0239 (0.9986)	accu 100.000 (97.450)
# Epoch-116 740 batches	loss 0.9447 (0.9984)	accu 98.438 (97.454)
# Epoch-116 760 batches	loss 0.9600 (0.9985)	accu 98.438 (97.449)
# Epoch-116 780 batches	loss 1.0372 (0.9983)	accu 95.312 (97.460)
# Epoch-116 800 batches	loss 0.9972 (0.9984)	accu 96.875 (97.449)
# Epoch-116 820 batches	loss 1.1157 (0.9983)	accu 93.750 (97.460)
# Epoch-116 840 batches	loss 0.9322 (0.9984)	accu 96.875 (97.444)
# Epoch-116 860 batches	loss 0.9927 (0.9985)	accu 95.312 (97.433)
# Epoch-116 880 batches	loss 0.9484 (0.9982)	accu 100.000 (97.449)
# Epoch-116 900 batches	loss 1.0426 (0.9980)	accu 96.875 (97.455)
# Epoch-116 920 batches	loss 1.0551 (0.9978)	accu 95.312 (97.461)
# Epoch-116 940 batches	loss 1.0254 (0.9978)	accu 96.875 (97.458)
# Epoch-116 960 batches	loss 0.9946 (0.9983)	accu 98.438 (97.445)
# Epoch-116 980 batches	loss 0.9861 (0.9982)	accu 98.438 (97.447)
# Epoch-116 1000 batches	loss 1.0270 (0.9982)	accu 95.312 (97.448)
# Epoch-116 1020 batches	loss 0.9784 (0.9980)	accu 98.438 (97.448)
# Epoch-116 1040 batches	loss 1.0639 (0.9981)	accu 93.750 (97.444)
# Epoch-116 1060 batches	loss 0.9649 (0.9985)	accu 100.000 (97.425)
# Epoch-116 1080 batches	loss 1.0065 (0.9985)	accu 96.875 (97.420)
# Epoch-116 1100 batches	loss 1.1034 (0.9988)	accu 93.750 (97.412)
# Epoch-116 1120 batches	loss 0.9848 (0.9987)	accu 98.438 (97.422)
# Epoch-116 1140 batches	loss 1.0268 (0.9988)	accu 98.438 (97.425)
# Epoch-116 1160 batches	loss 0.9941 (0.9990)	accu 96.875 (97.418)
# Epoch-116 1180 batches	loss 0.9742 (0.9989)	accu 96.875 (97.423)
# Epoch-116 1200 batches	loss 0.9577 (0.9988)	accu 96.875 (97.427)
# Epoch-116 1220 batches	loss 1.0102 (0.9986)	accu 96.875 (97.436)
# Epoch-116 282.4s	Train: loss 0.9986	accu 97.4355	Valid: loss 1.0528	accu 95.0166
# Epoch 116: val_acc did not improve
# 116 1.0000000000000002e-06
# Epoch-117  20 batches	loss 0.9049 (1.0108)	accu 100.000 (96.797)
# Epoch-117  40 batches	loss 0.9697 (1.0073)	accu 100.000 (97.070)
# Epoch-117  60 batches	loss 1.0057 (1.0072)	accu 96.875 (96.823)
# Epoch-117  80 batches	loss 0.9833 (1.0014)	accu 98.438 (97.246)
# Epoch-117 100 batches	loss 0.9600 (1.0006)	accu 100.000 (97.266)
# Epoch-117 120 batches	loss 1.0261 (0.9984)	accu 95.312 (97.331)
# Epoch-117 140 batches	loss 0.9840 (0.9979)	accu 98.438 (97.388)
# Epoch-117 160 batches	loss 1.0016 (0.9978)	accu 98.438 (97.412)
# Epoch-117 180 batches	loss 1.0062 (0.9971)	accu 93.750 (97.405)
# Epoch-117 200 batches	loss 1.0076 (0.9979)	accu 96.875 (97.422)
# Epoch-117 220 batches	loss 0.9903 (0.9990)	accu 98.438 (97.386)
# Epoch-117 240 batches	loss 1.0451 (1.0002)	accu 95.312 (97.344)
# Epoch-117 260 batches	loss 0.9128 (1.0003)	accu 100.000 (97.344)
# Epoch-117 280 batches	loss 0.9745 (1.0005)	accu 98.438 (97.377)
# Epoch-117 300 batches	loss 1.0071 (1.0012)	accu 98.438 (97.344)
# Epoch-117 320 batches	loss 0.9826 (1.0015)	accu 98.438 (97.339)
# Epoch-117 340 batches	loss 0.9996 (1.0004)	accu 100.000 (97.371)
# Epoch-117 360 batches	loss 0.9654 (0.9993)	accu 96.875 (97.418)
# Epoch-117 380 batches	loss 1.0506 (0.9994)	accu 95.312 (97.377)
# Epoch-117 400 batches	loss 1.0959 (0.9990)	accu 93.750 (97.387)
# Epoch-117 420 batches	loss 1.0486 (0.9997)	accu 95.312 (97.333)
# Epoch-117 440 batches	loss 0.9750 (0.9989)	accu 100.000 (97.383)
# Epoch-117 460 batches	loss 1.0756 (1.0001)	accu 93.750 (97.337)
# Epoch-117 480 batches	loss 0.9651 (1.0008)	accu 98.438 (97.327)
# Epoch-117 500 batches	loss 0.9695 (1.0004)	accu 98.438 (97.344)
# Epoch-117 520 batches	loss 0.9758 (1.0005)	accu 95.312 (97.326)
# Epoch-117 540 batches	loss 1.0576 (1.0006)	accu 95.312 (97.321)
# Epoch-117 560 batches	loss 0.9851 (1.0009)	accu 98.438 (97.316)
# Epoch-117 580 batches	loss 0.9612 (1.0010)	accu 100.000 (97.325)
# Epoch-117 600 batches	loss 0.9834 (1.0006)	accu 96.875 (97.339)
# Epoch-117 620 batches	loss 1.0454 (1.0008)	accu 93.750 (97.331)
# Epoch-117 640 batches	loss 1.0197 (1.0005)	accu 96.875 (97.336)
# Epoch-117 660 batches	loss 1.0214 (1.0005)	accu 95.312 (97.337)
# Epoch-117 680 batches	loss 0.9545 (0.9998)	accu 100.000 (97.351)
# Epoch-117 700 batches	loss 0.9924 (0.9998)	accu 98.438 (97.342)
# Epoch-117 720 batches	loss 0.9584 (1.0001)	accu 98.438 (97.350)
# Epoch-117 740 batches	loss 1.0490 (1.0006)	accu 98.438 (97.344)
# Epoch-117 760 batches	loss 0.9939 (1.0006)	accu 95.312 (97.346)
# Epoch-117 780 batches	loss 1.0257 (1.0008)	accu 93.750 (97.344)
# Epoch-117 800 batches	loss 0.9500 (1.0005)	accu 100.000 (97.354)
# Epoch-117 820 batches	loss 1.0299 (1.0009)	accu 98.438 (97.357)
# Epoch-117 840 batches	loss 1.0269 (1.0011)	accu 95.312 (97.347)
# Epoch-117 860 batches	loss 0.9716 (1.0008)	accu 100.000 (97.351)
# Epoch-117 880 batches	loss 0.9876 (1.0004)	accu 98.438 (97.369)
# Epoch-117 900 batches	loss 1.0213 (1.0003)	accu 96.875 (97.370)
# Epoch-117 920 batches	loss 0.9573 (1.0001)	accu 100.000 (97.371)
# Epoch-117 940 batches	loss 1.0027 (1.0001)	accu 96.875 (97.369)
# Epoch-117 960 batches	loss 1.0078 (0.9999)	accu 95.312 (97.376)
# Epoch-117 980 batches	loss 0.9884 (1.0001)	accu 95.312 (97.363)
# Epoch-117 1000 batches	loss 1.0477 (0.9999)	accu 95.312 (97.367)
# Epoch-117 1020 batches	loss 0.9792 (0.9996)	accu 96.875 (97.373)
# Epoch-117 1040 batches	loss 0.9566 (0.9997)	accu 100.000 (97.372)
# Epoch-117 1060 batches	loss 1.0512 (1.0002)	accu 93.750 (97.351)
# Epoch-117 1080 batches	loss 1.1034 (1.0002)	accu 90.625 (97.351)
# Epoch-117 1100 batches	loss 0.9740 (0.9998)	accu 96.875 (97.357)
# Epoch-117 1120 batches	loss 1.0144 (0.9997)	accu 93.750 (97.356)
# Epoch-117 1140 batches	loss 0.9389 (0.9998)	accu 100.000 (97.362)
# Epoch-117 1160 batches	loss 1.0369 (1.0001)	accu 93.750 (97.349)
# Epoch-117 1180 batches	loss 0.9595 (0.9999)	accu 100.000 (97.356)
# Epoch-117 1200 batches	loss 1.0230 (1.0000)	accu 95.312 (97.353)
# Epoch-117 1220 batches	loss 1.0357 (1.0000)	accu 96.875 (97.351)
# Epoch-117 288.4s	Train: loss 1.0002	accu 97.3355	Valid: loss 1.0558	accu 94.9751
# Epoch 117: val_acc did not improve
# 117 1.0000000000000002e-06
# Epoch-118  20 batches	loss 0.9573 (1.0062)	accu 96.875 (96.328)
# Epoch-118  40 batches	loss 1.0103 (0.9999)	accu 95.312 (96.875)
# Epoch-118  60 batches	loss 0.9476 (1.0002)	accu 100.000 (97.083)
# Epoch-118  80 batches	loss 1.0316 (1.0017)	accu 96.875 (97.109)
# Epoch-118 100 batches	loss 0.9597 (0.9994)	accu 98.438 (97.297)
# Epoch-118 120 batches	loss 1.0264 (0.9999)	accu 96.875 (97.279)
# Epoch-118 140 batches	loss 0.9930 (1.0013)	accu 98.438 (97.143)
# Epoch-118 160 batches	loss 0.9690 (1.0008)	accu 100.000 (97.148)
# Epoch-118 180 batches	loss 0.9582 (1.0009)	accu 100.000 (97.205)
# Epoch-118 200 batches	loss 0.9729 (1.0014)	accu 98.438 (97.195)
# Epoch-118 220 batches	loss 0.9897 (1.0010)	accu 98.438 (97.188)
# Epoch-118 240 batches	loss 0.9868 (1.0022)	accu 100.000 (97.181)
# Epoch-118 260 batches	loss 1.0301 (1.0016)	accu 95.312 (97.169)
# Epoch-118 280 batches	loss 1.0681 (1.0016)	accu 93.750 (97.176)
# Epoch-118 300 batches	loss 1.0013 (1.0025)	accu 98.438 (97.167)
# Epoch-118 320 batches	loss 0.9823 (1.0029)	accu 98.438 (97.192)
# Epoch-118 340 batches	loss 0.9664 (1.0023)	accu 100.000 (97.220)
# Epoch-118 360 batches	loss 0.9469 (1.0023)	accu 100.000 (97.209)
# Epoch-118 380 batches	loss 1.0174 (1.0025)	accu 98.438 (97.208)
# Epoch-118 400 batches	loss 1.0219 (1.0034)	accu 98.438 (97.180)
# Epoch-118 420 batches	loss 1.0281 (1.0040)	accu 98.438 (97.191)
# Epoch-118 440 batches	loss 0.9937 (1.0041)	accu 98.438 (97.205)
# Epoch-118 460 batches	loss 1.0068 (1.0039)	accu 95.312 (97.201)
# Epoch-118 480 batches	loss 0.9679 (1.0039)	accu 100.000 (97.230)
# Epoch-118 500 batches	loss 0.9944 (1.0037)	accu 98.438 (97.241)
# Epoch-118 520 batches	loss 0.9666 (1.0028)	accu 95.312 (97.254)
# Epoch-118 540 batches	loss 0.9875 (1.0025)	accu 100.000 (97.283)
# Epoch-118 560 batches	loss 0.9921 (1.0025)	accu 96.875 (97.285)
# Epoch-118 580 batches	loss 1.2208 (1.0024)	accu 90.625 (97.282)
# Epoch-118 600 batches	loss 1.0093 (1.0019)	accu 95.312 (97.299)
# Epoch-118 620 batches	loss 0.9787 (1.0016)	accu 100.000 (97.316)
# Epoch-118 640 batches	loss 1.0233 (1.0015)	accu 95.312 (97.324)
# Epoch-118 660 batches	loss 0.9801 (1.0014)	accu 96.875 (97.306)
# Epoch-118 680 batches	loss 0.9915 (1.0018)	accu 96.875 (97.289)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 111
#     108     model = model.cuda()
#     109     test(test_loader, model, checkpoint, lable_path, pred_path)
# --> 111 main()
#
# Cell In[11], line 64, in main()
#      61 print(epoch, optimizer.param_groups[0]['lr'])
#      63 t_start = time.time()
# ---> 64 train_loss, train_acc = train(
#      65     train_loader, model, criterion, optimizer, epoch)
#      66 val_loss, val_acc = validate(val_loader, model, criterion)
#      67 log_res += [[train_loss, train_acc.cpu().numpy(),
#      68              val_loss, val_acc.cpu().numpy()]]
#
# Cell In[9], line 6, in train(train_loader, model, criterion, optimizer, epoch)
#       3 acces = AverageMeter()
#       4 model.train()
# ----> 6 for i, (inputs, target) in enumerate(train_loader):
#       8     output = model(inputs.cuda())
#       9     target = target.cuda()
#
# File c:\Users\Carrt\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\utils\data\dataloader.py:628, in _BaseDataLoaderIter.__next__(self)
#     625 if self._sampler_iter is None:
#     626     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627     self._reset()  # type: ignore[call-arg]
# --> 628 data = self._next_data()
#     629 self._num_yielded += 1
#     630 if self._dataset_kind == _DatasetKind.Iterable and \
#     631         self._IterableDataset_len_called is not None and \
#     632         self._num_yielded > self._IterableDataset_len_called:
#
# File c:\Users\Carrt\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\utils\data\dataloader.py:671, in _SingleProcessDataLoaderIter._next_data(self)
#     669 def _next_data(self):
#     670     index = self._next_index()  # may raise StopIteration
# --> 671     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672     if self._pin_memory:
#     673         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\Carrt\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\utils\data\_utils\fetch.py:61, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
# ---> 61 return self.collate_fn(data)
#
# File c:\Users\Carrt\OneDrive\Code\Motion Privacy\Attacking Models\SGN Attack Model\data.py:146, in NTUDataLoaders.collate_fn_fix_val(self, batch)
#     143 """Puts each data field into a tensor with outer dimension batch size
#     144 """
#     145 x, y = zip(*batch)
# --> 146 x, y = self.Tolist_fix(x, y, train=1)
#     147 idx = range(len(x))
#     148 y = np.array(y)
#
# File c:\Users\Carrt\OneDrive\Code\Motion Privacy\Attacking Models\SGN Attack Model\data.py:174, in NTUDataLoaders.Tolist_fix(self, joints, y, train)
#     172 zero_row = []
#     173 for i in range(len(seq)):
# --> 174     if (seq[i, :] == np.zeros((1, 150))).all():
#     175         zero_row.append(i)
#     177 seq = np.delete(seq, zero_row, axis=0)
#
# KeyboardInterrupt:
